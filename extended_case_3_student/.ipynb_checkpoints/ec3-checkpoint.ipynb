# %% [markdown]
# # Finding our best-performing salespeople and products

# %% [markdown]
# ## Introduction

# %% [markdown]
# **Business Context.** You work for AdventureWorks, a company that sells outdoor sporting equipment. The company has many different locations and has been recording the sales of different locations on various products. You, their new data scientist, have been tasked with the question: **"What are our best products and salespeople and how can use this information to improve our overall performance?"**
#
# You have been given access to the relevant data files with documentation from the IT department. Your job is to extract meaningful insights from these data files to help increase sales. First, you will look at the best products and try to see how different products behave in different categories. Second, you will analyze the best salespeople to see if the commission percentage motivates them to sell more.

# %% [markdown]
# **Business Problem.** Your task is to **construct a database from the provided CSV files and then write queries in SQL to carry out the requested analysis**.

# %% [markdown]
# **Analytical Context.** You are given the data (stored in the ```data/csvs``` folder) as a set of separate CSV files, each one representing a table. You will build a new PostgreSQL database from these files using AWS RDS.
#
# The company has been pretty vague about how they expect you to extract insights, but you have come up with the following plan of attack:
#
# 1. Create the database and ensure you can run basic queries against it
# 2. Look at how product ratings and total sales are related
# 3. See how products sell in different subcategories (bikes, helmets, socks, etc.)
# 4. Calculate which salespeople have performed the best in the past year
# 5. Seeing if total sales are correlated with their commission percentage
#
# Of course, this is only your initial plan. As you explore the database, your strategy will change.

# %% [markdown]
# ## Setting up AWS

# %% [markdown]
# In this case, we'll assume that the company has given you an entry-level laptop, which is not capable of running a PostgreSQL server locally. Therefore, you should set up a cloud database, connect to it from `psql`, and run the analysis via the `psql` or directly from the notebook.

# %% [markdown]
# ### Question:
#
# Repeat the steps in Case 12.3 to create a new RDS instance with a PostgreSQL database.

# %% [markdown]
# ## Overview of the data

# %% [markdown]
# The data for the case is contained in the ```./data/csvs``` directory; specifically, it is the ```AdventureWorks``` sample data provided by Microsoft. We will be focusing on the Sales and Production categories. Complete documentation for the original data (of which you have only a subset) can be found [here](https://dataedo.com/download/AdventureWorks.pdf).
#
# **Product Tables:**
# * **Product**: one row per product that the company sells
# * **ProductReview**: one row per rating and review left by customers
# * **ProductModelProductDescriptionCulture**: a link between products and their longer descriptions also indicating a "culture" - which language and region the product is for
# * **ProductDescription**: a longer description of each product, for a specific region
# * **ProductCategory**: the broad categories that products fit into
# * **ProductSubCategory**: the narrower subcategories that products fit into
#
# **Sales Tables:**
# * **SalesPerson**: one row per salesperson, including information on their commission and performance
# * **SalesOrderHeader**: one row per sale summarizing the sale
# * **SalesOrderDetail**: many rows per sale, detailing each product that forms part of the sale
# * **SalesTerritory**: the different territories where products are sold, including performance
#
# **Region Tables:**
# * **CountryRegionCurrency**: the currency used by each region
# * **CurrencyRate**: the average and closing exchange rates for each currency compared to the USD

# %% [markdown]
# ## Setting up `ipython-sql` and `pgspecial`
#
# Jupyter notebook is usually used to run Python code, but with an add-on it can run SQL directly against a database too. Install the extensions `ipython-sql` and `pgspecial` through `pip` (you may have to restart the notebook after doing this) and create the database `adventureworks`:

# %%
# !pip3 install ipython-sql pgspecial
# Out:
# Collecting ipython-sql
#   Downloading https://files.pythonhosted.org/packages/ab/3d/0d38357c620df31cebb056ca1804027112e5c008f4c2c0e16d879996ad9f/ipython_sql-0.4.0-py3-none-any.whl
# Collecting pgspecial
#   Downloading https://files.pythonhosted.org/packages/34/70/f20df1e335592ace0e4f54989307d1630163445599b6abd43a2e0149d483/pgspecial-1.11.10-py3-none-any.whl
# Collecting sqlparse
#   Downloading https://files.pythonhosted.org/packages/85/ee/6e821932f413a5c4b76be9c5936e313e4fc626b33f16e027866e1d60f588/sqlparse-0.3.1-py2.py3-none-any.whl (40kB)
#      |████████████████████████████████| 40kB 7.8MB/s  eta 0:00:01
# Requirement already satisfied: ipython>=1.0 in /Users/tongzhan/anaconda3/lib/python3.7/site-packages (from ipython-sql) (6.5.0)
# Requirement already satisfied: sqlalchemy>=0.6.7 in /Users/tongzhan/anaconda3/lib/python3.7/site-packages (from ipython-sql) (1.2.11)
# Collecting prettytable<1
#   Downloading https://files.pythonhosted.org/packages/ef/30/4b0746848746ed5941f052479e7c23d2b56d174b82f4fd34a25e389831f5/prettytable-0.7.2.tar.bz2
# Requirement already satisfied: six in /Users/tongzhan/anaconda3/lib/python3.7/site-packages (from ipython-sql) (1.11.0)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /Users/tongzhan/anaconda3/lib/python3.7/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: click>=4.1 in /Users/tongzhan/anaconda3/lib/python3.7/site-packages (from pgspecial) (6.7)
# Requirement already satisfied: psycopg2>=2.7.4 in /Users/tongzhan/anaconda3/lib/python3.7/site-packages (from pgspecial) (2.8.2)
# Requirement already satisfied: simplegeneric>0.8 in /Users/tongzhan/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (0.8.1)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /Users/tongzhan/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (4.6.0)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.15 in /Users/tongzhan/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (1.0.15)
# Requirement already satisfied: decorator in /Users/tongzhan/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (4.3.0)
# Requirement already satisfied: traitlets>=4.2 in /Users/tongzhan/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (4.3.2)
# Requirement already satisfied: jedi>=0.10 in /Users/tongzhan/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (0.12.1)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /Users/tongzhan/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (0.1.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/tongzhan/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (42.0.0)
# Requirement already satisfied: backcall in /Users/tongzhan/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (0.1.0)
# Requirement already satisfied: pygments in /Users/tongzhan/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (2.2.0)
# Requirement already satisfied: pickleshare in /Users/tongzhan/anaconda3/lib/python3.7/site-packages (from ipython>=1.0->ipython-sql) (0.7.4)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/tongzhan/anaconda3/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython>=1.0->ipython-sql) (0.6.0)
# Requirement already satisfied: wcwidth in /Users/tongzhan/anaconda3/lib/python3.7/site-packages (from prompt-toolkit<2.0.0,>=1.0.15->ipython>=1.0->ipython-sql) (0.1.7)
# Requirement already satisfied: parso>=0.3.0 in /Users/tongzhan/anaconda3/lib/python3.7/site-packages (from jedi>=0.10->ipython>=1.0->ipython-sql) (0.3.1)
# Building wheels for collected packages: prettytable
#   Building wheel for prettytable (setup.py) ... done
#   Created wheel for prettytable: filename=prettytable-0.7.2-cp37-none-any.whl size=12666 sha256=11d0421628ecd487428af89f1afc1e203c3fec52600c2897c88c39afb58106b0
#   Stored in directory: /Users/tongzhan/Library/Caches/pip/wheels/80/34/1c/3967380d9676d162cb59513bd9dc862d0584e045a162095606
# Successfully built prettytable
# Installing collected packages: sqlparse, prettytable, ipython-sql, pgspecial
# Successfully installed ipython-sql-0.4.0 pgspecial-1.11.10 prettytable-0.7.2 sqlparse-0.3.1
# WARNING: You are using pip version 19.3.1; however, version 20.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# Now load the sql add-on and connect to the database as follows. You'll need to change the username (`postgres`), password (`mysecretpassword`), host (`localhost`), and database name (`postgres`) to what you used when setting up your RDS instance:

# %%
# %load_ext sql

# %sql postgresql://user:password@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/adventuretime
# Out:
# 'Connected: ec3_user@adventuretime'

# %% [markdown]
# You should now be able to run SQL directly from any Jupyter notebook cell by starting the cell with a line that states `%%sql`. For example (once you have a database with some tables, which we'll only create later):
#
# ```sql
# %%sql
#
# SELECT * FROM product LIMIT 10;
# ```
#
# **Note:** Unlike `pandas` which automatically truncates output for large DataFrames, the SQL plug-in gives you exactly what you ask for. If you do a `SELECT * FROM` a table with a million rows and no `LIMIT` clause, it'll output all million rows and probably freeze your notebook. It's good practice to always use a `LIMIT` clause even when it's not needed to avoid any mishaps.

# %% [markdown]
# ## Creating the database and adding the tables
#
# Now, let's create a database called `adventuretime`. (If you do this through the notebook, you'll have to add the line `end;` before your `create database` command as the add-on runs everything in transactions).
#
# You'll need to add a table for each of the CSV files. Spend some time looking at the different CSV files and getting used to how they reference each other and what headers they create. Then, you'll need to write an appropriate `CREATE TABLE` command with appropriate types. You can figure out the types by inspecting the CSV files and/or referencing the documentation.

# %% [markdown]
# ### Exercise 1:
#
# Write all of the commands that you need to
#
# * Create the database
# * Create the tables
# * Import the data from the CSVs
#
# **Hint:** As an example, to add data for the `salesperson` table, you would use the following commands:
#
# 1. Create table (can be run from Jupyter Notebook or the `psql` command line interface):
# ```sql
# CREATE TABLE salesperson (
#     businessentityid INTEGER,
#     territoryid INTEGER,
#     salesquota INTEGER,
#     bonus INTEGER,
#     commissionpct FLOAT,
#     salesytd FLOAT,
#     saleslastyear FLOAT,
#     rowguid TEXT,
#     modifieddate DATE
#     );
# ```
#
# 2. Copy data (has to be run from the `psql` shell):
#
# ```sql
# \copy salesperson FROM 'data/csvs/salesperson.csv' with (format CSV, header true, delimiter ',');
# ```

# %% [markdown]
# **Answer.**

# %%
# %%sql
# end;
# create database adventuretime;
# Out:
#  * postgresql://postgres:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/postgres
# Done.
# Done.
# []

# %%
# %%sql
#
# grant all privileges on database adventuretime to user;
# Out:
#  * postgresql://postgres:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/postgres
# Done.
# []

# %%
# %%sql
#
# CREATE TABLE countryregioncurrency(
#   countryregioncode VARCHAR,
#   currencycode VARCHAR,
#   modifieddate TIMESTAMP
# );
# Out:
#  * postgresql://postgres:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/postgres
# (psycopg2.errors.DuplicateTable) relation "countryregioncurrency" already exists
#
# [SQL: CREATE TABLE countryregioncurrency(
#   countryregioncode VARCHAR,
#   currencycode VARCHAR,
#   modifieddate TIMESTAMP
# );]
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
# %%sql
#
# CREATE TABLE currencyrate(currencyrateid INT,
# currencyratedate TIMESTAMP,
# fromcurrencycode VARCHAR,
# tocurrencycode VARCHAR,
# averagerate DECIMAL,
# endofdayrate DECIMAL,
# modifieddate TIMESTAMP);
# Out:
#  * postgresql://ec3_user:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/adventuretime
# Done.
# []

# %%
# %%sql
#
# CREATE TABLE IF NOT EXISTS product(
#   productid INT,
#   name VARCHAR,
#   productnumber VARCHAR,
#   makeflag VARCHAR,
#   finishedgoodsflag VARCHAR,
#   color VARCHAR,
#   safetystocklevel DECIMAL,
#   reorderpoint DECIMAL,
#   standardcost DECIMAL,
#   listprice DECIMAL,
#   size VARCHAR,
#   sizeunitmeasurecode VARCHAR,
#   weightunitmeasurecode VARCHAR,
#   weight FLOAT,
#   daystomanufacture DECIMAL,
#   productline VARCHAR,
#   class VARCHAR,
#   style VARCHAR,
#   productsubcategoryid INT,
#   productmodelid INT,
#   sellstartdate TIMESTAMP,
#   sellenddate TIMESTAMP,
#   discontinueddate TIMESTAMP,
#   rowguid VARCHAR,
#   modifieddate TIMESTAMP
# );
# Out:
#  * postgresql://ec3_user:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/adventuretime
#    postgresql://postgres:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/postgres
# Done.
# []

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS productcategory(
#   productcategoryid INT,
#   name VARCHAR,
#   rowguid VARCHAR,
#   modifieddate TIMESTAMP
# );
# Out:
#  * postgresql://ec3_user:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/adventuretime
#    postgresql://postgres:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/postgres
# Done.
# []

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS productdescription(
#   productdescriptionid INT,
#   description VARCHAR,
#   rowguid VARCHAR,
#   modifieddate TIMESTAMP
# );
# Out:
#  * postgresql://ec3_user:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/adventuretime
#    postgresql://postgres:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/postgres
# Done.
# []

# %%
# %%sql
#
# CREATE TABLE IF NOT EXISTS productmodelproductdescriptionculture(
#   productmodelid INT,
#   productdescriptionid DECIMAL,
#   cultureid VARCHAR,
#   modifieddate TIMESTAMP
# );
# Out:
#  * postgresql://ec3_user:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/adventuretime
#    postgresql://postgres:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/postgres
# Done.
# []

# %%
# %%sql
#
# CREATE TABLE IF NOT EXISTS productreview(
#   productreviewid INT,
#   productid DECIMAL,
#   reviewername VARCHAR,
#   reviewdate TIMESTAMP,
#   emailaddress VARCHAR,
#   rating DECIMAL,
#   comments VARCHAR,
#   modifieddate TIMESTAMP
# );
# Out:
#  * postgresql://ec3_user:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/adventuretime
#    postgresql://postgres:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/postgres
# Done.
# []

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS productsubcategory(
#   productsubcategoryid INT,
#   productcategoryid DECIMAL,
#   name VARCHAR,
#   rowguid VARCHAR,
#   modifieddate TIMESTAMP
# );
# Out:
#  * postgresql://ec3_user:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/adventuretime
#    postgresql://postgres:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/postgres
# Done.
# []

# %%
# %%sql
#
# CREATE TABLE IF NOT EXISTS salesorderdetail(
#   salesorderid DECIMAL,
#   salesorderdetailid DECIMAL,
#   carriertrackingnumber VARCHAR,
#   orderqty INT,
#   productid DECIMAL,
#   specialofferid INT,
#   unitprice FLOAT,
#   unitpricediscount FLOAT,
#   rowguid VARCHAR,
#   modifieddate TIMESTAMP
# );
# Out:
#  * postgresql://ec3_user:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/adventuretime
#    postgresql://postgres:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/postgres
# Done.
# []

# %%
# %%sql
#
# CREATE TABLE IF NOT EXISTS salesorderheader(
#   salesorderid INT,
#   revisionnumber DECIMAL,
#   orderdate TIMESTAMP,
#   duedate TIMESTAMP,
#   shipdate TIMESTAMP,
#   status DECIMAL,
#   onlineorderflag VARCHAR,
#   purchaseordernumber VARCHAR,
#   accountnumber VARCHAR,
#   customerid DECIMAL,
#   salespersonid DECIMAL,
#   territoryid DECIMAL,
#   billtoaddressid DECIMAL,
#   shiptoaddressid DECIMAL,
#   shipmethodid DECIMAL,
#   creditcardid INT,
#   creditcardapprovalcode VARCHAR,
#   currencyrateid DECIMAL,
#   subtotal FLOAT,
#   taxamt FLOAT,
#   freight FLOAT,
#   totaldue FLOAT,
#   comment VARCHAR,
#   rowguid VARCHAR,
#   modifieddate TIMESTAMP
# );
# Out:
#  * postgresql://ec3_user:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/adventuretime
#    postgresql://postgres:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/postgres
# Done.
# []

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS salesperson(
#   businessentityid INT,
#   territoryid INT,
#   salesquota DECIMAL,
#   bonus DECIMAL,
#   commissionpct FLOAT,
#   salesytd FLOAT,
#   saleslastyear FLOAT,
#   rowguid VARCHAR,
#   modifieddate TIMESTAMP
# );
# Out:
#  * postgresql://ec3_user:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/adventuretime
#    postgresql://postgres:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/postgres
# Done.
# []

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS salesterritory(
#   territoryid INT,
#   name VARCHAR,
#   countryregioncode VARCHAR,
#   group1 VARCHAR,
#   salesytd FLOAT,
#   saleslastyear FLOAT,
#   costytd DECIMAL,
#   costlastyear DECIMAL,
#   rowguid VARCHAR,
#   modifieddate TIMESTAMP
# );
# Out:
#  * postgresql://ec3_user:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/adventuretime
#    postgresql://postgres:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/postgres
# Done.
# []

# %% [markdown]
# ---------

# %% [markdown]
# ## Finding our most popular products

# %% [markdown]
# As discussed, the company would like to know which of their products is the most popular among customers. You figure that the average rating given in reviews is correlated with the number of sales of a particular product (that products with higher reviews have more sales).

# %% [markdown]
# ### Exercise 2:
#
# Using the ```product``` and ```productreview``` tables, ```JOIN``` them and rank the products according to their average review rating. What are the names and IDs of the top 5 products?

# %% [markdown]
# **Answer.**

# %% [markdown]
# ---------

# %%
# %%sql
#
# SELECT P.productid, P.name, AVG(rating) AS AverageRating
# FROM product P
#     JOIN productreview PR ON P.productid = PR.productid
# GROUP BY P.productid, P.name
# ORDER BY AverageRating
# LIMIT 5;
# Out:
#  * postgresql://ec3_user:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/adventuretime
#    postgresql://postgres:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/postgres
# 3 rows affected.
# [(937, 'HL Mountain Pedal', Decimal('3.0000000000000000')),
#  (798, 'Road-550-W Yellow, 40', Decimal('5.0000000000000000')),
#  (709, 'Mountain Bike Socks, M', Decimal('5.0000000000000000'))]

# %% [markdown]
# There are only 3 products with reviews

# %% [markdown]
# ### Exercise 3:
#
# Much to your disappointment, there are only three products with ratings and only four reviews in total! This is nowhere near enough to perform an analysis of the correlation between reviews and total sales.
#
# Nevertheless, your manager wants the **English description** of these products for an upcoming sale. Use the documentation provided above if you need help navigating the structure to extract this!
#
# **Hint:** You'll notice that the value for `cultureid` in the `productmodelproductdescriptionculture` table often has extra trailing spaces which makes it difficult to reliably get descriptions of a specific language. You should first modify this table before writing the `SELECT` statement to get the descriptions that your manager wants. To do this, you can use an `UPDATE` statement with Postgres's [`TRIM`](https://w3resource.com/PostgreSQL/trim-function.php) function.

# %% [markdown]
# **Answer.**

# %% [markdown]
# ---------

# %% [markdown]
# First update the values of the table to delete trailing spaces

# %%
# %%sql
#
# UPDATE productmodelproductdescriptionculture
# SET cultureid=TRIM(TRAILING  FROM cultureid);
# Out:
#  * postgresql://ec3_user:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/adventuretime
#    postgresql://postgres:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/postgres
# 762 rows affected.
# []

# %% [markdown]
# Here whe have a table with the descriptions for product models

# %%
# %%sql
#
# SELECT productmodelid, PM.productdescriptionid, PM.cultureid, description
# FROM productmodelproductdescriptionculture AS PM
#     JOIN productdescription PD ON PM.productdescriptionid = PD.productdescriptionid
# WHERE PM.cultureid LIKE 'en';
# Out:
#  * postgresql://ec3_user:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/adventuretime
#    postgresql://postgres:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/postgres
# 127 rows affected.
# [(95, Decimal('3'), 'en', 'Chromoly steel.'),
#  (96, Decimal('4'), 'en', 'Aluminum alloy cups; large diameter spindle.'),
#  (97, Decimal('5'), 'en', 'Aluminum alloy cups and a hollow axle.'),
#  (23, Decimal('8'), 'en', 'Suitable for any type of riding, on or off-road. Fits any budget. Smooth-shifting with a comfortable ride.'),
#  (22, Decimal('64'), 'en', 'This bike delivers a high-level of performance on a budget. It is responsive and maneuverable, and offers peace-of-mind when you decide to go off-road.'),
#  (21, Decimal('88'), 'en', 'For true trail addicts.  An extremely durable bike that will go anywhere and keep you in control on challenging terrain - without breaking your budget.'),
#  (20, Decimal('128'), 'en', 'Serious back-country riding. Perfect for all levels of competition. Uses the same HL Frame as the Mountain-100.'),
#  (19, Decimal('168'), 'en', 'Top-of-the-line competition mountain bike. Performance-enhancing options include the innovative HL Frame, super-smooth front suspension, and traction for all terrain.'),
#  (39, Decimal('170'), 'en', 'Suitable for any type of off-road trip. Fits any budget.'),
#  (31, Decimal('209'), 'en', 'Entry level adult bike; offers a comfortable ride cross-country or down the block. Quick-release hubs and rims.'),
#  (30, Decimal('249'), 'en', "Value-priced bike with many features of our top-of-the-line models. Has the same light, stiff frame, and the quick acceleration we're famous for."),
#  (29, Decimal('320'), 'en', 'Same technology as all of our Road series bikes, but the frame is sized for a woman.  Perfect all-around bike for road or racing.'),
#  (40, Decimal('321'), 'en', 'Same technology as all of our Road series bikes.  Perfect all-around bike for road or racing.'),
#  (28, Decimal('337'), 'en', 'A true multi-sport bike that offers streamlined riding and a revolutionary design. Aerodynamic design lets you ride with the pros, and the gearing will conquer hilly roads.'),
#  (41, Decimal('375'), 'en', 'Cross-train, race, or just socialize on a sleek, aerodynamic bike.  Advanced seat technology provides comfort all day.'),
#  (27, Decimal('376'), 'en', 'Cross-train, race, or just socialize on a sleek, aerodynamic bike designed for a woman.  Advanced seat technology provides comfort all day.'),
#  (26, Decimal('409'), 'en', 'Alluminum-alloy frame provides a light, stiff ride, whether you are racing in the velodrome or on a demanding club ride on country roads.'),
#  (25, Decimal('457'), 'en', 'This bike is ridden by race winners. Developed with the Adventure Works Cycles professional race team, it has a extremely light heat-treated aluminum frame, and steering that allows precision control.'),
#  (36, Decimal('513'), 'en', 'All-occasion value bike with our basic comfort and safety features. Offers wider, more stable tires for a ride around town or weekend trip.'),
#  (35, Decimal('554'), 'en', "The plush custom saddle keeps you riding all day,  and there's plenty of space to add panniers and bike bags to the newly-redesigned carrier.  This bike has stability when fully-loaded."),
#  (34, Decimal('594'), 'en', 'Travel in style and comfort. Designed for maximum comfort and safety. Wide gear range takes on all hills. High-tech aluminum alloy construction provides durability without added weight.'),
#  (98, Decimal('613'), 'en', 'Superior shifting performance.'),
#  (99, Decimal('618'), 'en', 'Super rigid spindle.'),
#  (100, Decimal('619'), 'en', 'High-strength crank arm.'),
#  (101, Decimal('620'), 'en', 'Triple crankset; alumunim crank arm; flawless shifting.'),
#  (102, Decimal('627'), 'en', 'All-weather brake pads; provides superior stopping by applying more surface to the rim.'),
#  (103, Decimal('630'), 'en', 'Wide-link design.'),
#  (104, Decimal('633'), 'en', 'Stout design absorbs shock and offers more precise steering.'),
#  (105, Decimal('634'), 'en', 'Composite road fork with an aluminum steerer tube.'),
#  (106, Decimal('635'), 'en', 'High-performance carbon road fork with curved legs.'),
#  (8, Decimal('637'), 'en', 'Our best value utilizing the same, ground-breaking frame technology as the ML aluminum frame.'),
#  (15, Decimal('642'), 'en', "The ML frame is a heat-treated aluminum frame made with the same detail and quality as our HL frame. It offers superior performance. Men's version."),
#  (14, Decimal('644'), 'en', "The ML frame is a heat-treated aluminum frame made with the same detail and quality as our HL frame. It offers superior performance. Women's version."),
#  (5, Decimal('647'), 'en', 'Each frame is hand-crafted in our Bothell facility to the optimum diameter and wall-thickness required of a premium mountain frame. The heat-treated welded aluminum frame has a larger diameter tube that absorbs the bumps.'),
#  (17, Decimal('661'), 'en', "Made from the same aluminum alloy as our top-of-the line HL frame, the ML features a lightweight down-tube milled to the perfect diameter for optimal strength. Women's version."),
#  (42, Decimal('686'), 'en', 'Replacement mountain wheel for entry-level rider.'),
#  (45, Decimal('687'), 'en', 'Replacement mountain wheel for the casual to serious rider.'),
#  (46, Decimal('688'), 'en', 'High-performance mountain replacement wheel.'),
#  (49, Decimal('689'), 'en', 'Replacement road front wheel for entry-level cyclist.'),
#  (50, Decimal('690'), 'en', 'Sturdy alloy features a quick-release hub.'),
#  (51, Decimal('691'), 'en', 'Strong wheel with double-walled rim.'),
#  (44, Decimal('692'), 'en', 'Aerodynamic rims for smooth riding.'),
#  (52, Decimal('697'), 'en', 'All-purpose bar for on or off-road.'),
#  (54, Decimal('698'), 'en', 'Tough aluminum alloy bars for downhill.'),
#  (55, Decimal('699'), 'en', 'Flat bar strong enough for the pro circuit.'),
#  (56, Decimal('700'), 'en', 'Unique shape provides easier reach to the levers.'),
#  (57, Decimal('701'), 'en', 'Anatomically shaped aluminum tube bar will suit all riders.'),
#  (58, Decimal('702'), 'en', 'Designed for racers; high-end anatomically shaped bar from aluminum alloy.'),
#  (47, Decimal('703'), 'en', 'Unique shape reduces fatigue for entry level riders.'),
#  (48, Decimal('704'), 'en', 'A light yet stiff aluminum bar for long distance riding.'),
#  (59, Decimal('744'), 'en', 'Threadless headset provides quality at an economical price.'),
#  (60, Decimal('745'), 'en', 'Sealed cartridge keeps dirt out.'),
#  (61, Decimal('746'), 'en', 'High-quality 1 threadless headset with a grease port for quick lubrication.'),
#  (62, Decimal('847'), 'en', 'Expanded platform so you can ride in any shoes; great for all-around riding.'),
#  (63, Decimal('848'), 'en', 'Lightweight, durable, clipless pedal with adjustable tension.'),
#  (64, Decimal('849'), 'en', 'Stainless steel; designed to shed mud easily.'),
#  (68, Decimal('850'), 'en', 'Clipless pedals - aluminum.'),
#  (69, Decimal('851'), 'en', 'Lightweight aluminum alloy construction.'),
#  (70, Decimal('852'), 'en', 'Top-of-the-line clipless pedals with adjustable tension.'),
#  (53, Decimal('853'), 'en', 'A stable pedal for all-day riding.'),
#  (71, Decimal('856'), 'en', 'Refillable shoes; polished aluminum calipers.'),
#  (72, Decimal('858'), 'en', '10-speed aluminum derailleur with sealed pulley bearings.'),
#  (73, Decimal('867'), 'en', 'Replacement rear mountain wheel for entry-level rider.'),
#  (74, Decimal('868'), 'en', 'Replacement rear mountain wheel for the casual to serious rider.'),
#  (75, Decimal('869'), 'en', 'Extra-strong rims guarantee durability.'),
#  (76, Decimal('870'), 'en', 'Replacement rear wheel for entry-level cyclist.'),
#  (77, Decimal('871'), 'en', 'Aluminum alloy rim with stainless steel spokes; built for speed.'),
#  (78, Decimal('872'), 'en', 'Strong rear wheel with double-walled rim.'),
#  (43, Decimal('873'), 'en', 'Excellent aerodynamic rims guarantee a smooth ride.'),
#  (79, Decimal('885'), 'en', 'Synthetic leather. Features gel for increased comfort.'),
#  (80, Decimal('886'), 'en', 'Designed to absorb shock.'),
#  (81, Decimal('887'), 'en', 'Anatomic design for a full-day of riding in comfort. Durable leather.'),
#  (82, Decimal('888'), 'en', 'Lightweight foam-padded saddle.'),
#  (83, Decimal('889'), 'en', 'Rubber bumpers absorb bumps.'),
#  (84, Decimal('890'), 'en', 'Lightweight kevlar racing saddle. Leather.'),
#  (66, Decimal('891'), 'en', 'Comfortable, ergonomically shaped gel saddle.'),
#  (65, Decimal('892'), 'en', 'New design relieves pressure for long rides.'),
#  (67, Decimal('893'), 'en', 'Cut-out shell for a more comfortable ride.'),
#  (85, Decimal('903'), 'en', 'Comparible traction, less expensive wire bead casing.'),
#  (86, Decimal('904'), 'en', 'Great traction, high-density rubber.'),
#  (87, Decimal('905'), 'en', 'Incredible traction, lightweight carbon reinforced.'),
#  (88, Decimal('906'), 'en', 'Same great treads as more expensive tire with a less expensive wire bead casing.'),
#  (89, Decimal('907'), 'en', 'Higher density rubber.'),
#  (90, Decimal('908'), 'en', 'Lightweight carbon reinforced  for an unrivaled ride at an un-compromised weight.'),
#  (91, Decimal('909'), 'en', 'High-density rubber.'),
#  (92, Decimal('912'), 'en', 'Self-sealing tube.'),
#  (93, Decimal('913'), 'en', 'Conventional all-purpose tube.'),
#  (94, Decimal('914'), 'en', 'General purpose tube.'),
#  (9, Decimal('1020'), 'en', 'The LL Frame provides a safe comfortable ride, while offering superior bump absorption in a value-priced aluminum frame.'),
#  (16, Decimal('1062'), 'en', "Made from the same aluminum alloy as our top-of-the line HL frame, the ML features a lightweight down-tube milled to the perfect diameter for optimal strength. Men's version."),
#  (6, Decimal('1090'), 'en', 'Our lightest and best quality aluminum frame made from the newest alloy; it is welded and heat-treated for strength. Our innovative design results in maximum comfort and performance.'),
#  (10, Decimal('1146'), 'en', 'Lightweight butted aluminum frame provides a more upright riding position for a trip around town.  Our ground-breaking design provides optimum comfort.'),
#  (7, Decimal('1182'), 'en', "The HL aluminum frame is custom-shaped for both good looks and strength; it will withstand the most rigorous challenges of daily riding. Men's version."),
#  (108, Decimal('1183'), 'en', 'Affordable light for safe night riding - uses 3 AAA batteries'),
#  (113, Decimal('1185'), 'en', 'Aluminum cage is lighter than our mountain version; perfect for long distance trips.'),
#  (111, Decimal('1186'), 'en', 'AWC logo water bottle - holds 30 oz; leak-proof.'),
#  (118, Decimal('1187'), 'en', 'Carries 4 bikes securely; steel construction, fits 2 receiver hitch.'),
#  (121, Decimal('1188'), 'en', 'Clip-on fenders fit most mountain bikes.'),
#  (18, Decimal('1189'), 'en', 'Combination of natural and synthetic fibers stays dry and provides just the right cushioning.'),
#  (116, Decimal('1191'), 'en', 'Designed for convenience. Fits in your pocket. Aluminum barrel. 160psi rated.'),
#  (12, Decimal('1192'), 'en', 'Designed for the AWC team with stay-put straps, moisture-control, chamois padding, and leg grippers.'),
#  (120, Decimal('1193'), 'en', 'Durable, water-proof nylon construction with easy access. Large enough for weekend trips.'),
#  (4, Decimal('1194'), 'en', 'Full padding, improved finger flex, durable palm, adjustable closure.'),
#  (3, Decimal('1195'), 'en', 'Synthetic palm, flexible knuckles, breathable mesh upper. Worn by the AWC team riders.'),
#  (37, Decimal('1196'), 'en', 'Heavy duty, abrasion-resistant shorts feature seamless, lycra inner shorts with anti-bacterial chamois for comfort.'),
#  (114, Decimal('1197'), 'en', 'Includes 8 different size patches, glue and sandpaper.'),
#  (1, Decimal('1199'), 'en', 'Light-weight, wind-resistant, packs to fit into a pocket.'),
#  (13, Decimal('1200'), 'en', "Men's 8-panel racing shorts - lycra with an elastic waistband and leg grippers."),
#  (122, Decimal('1201'), 'en', 'Perfect all-purpose bike stand for working on your bike at home. Quick-adjusting clamps and steel construction.'),
#  (109, Decimal('1202'), 'en', 'Rechargeable dual-beam headlight.'),
#  (110, Decimal('1203'), 'en', 'Rugged weatherproof headlight.'),
#  (32, Decimal('1205'), 'en', 'Short sleeve classic breathable jersey with superior moisture control, front zipper, and 3 back pockets.'),
#  (117, Decimal('1206'), 'en', 'Simple and light-weight. Emergency patches stored in handle.'),
#  (24, Decimal('1208'), 'en', 'Thin, lightweight and durable with cuffs that stay up.'),
#  (112, Decimal('1209'), 'en', 'Tough aluminum cage holds bottle securly on tough terrain.'),
#  (2, Decimal('1210'), 'en', 'Traditional style with a flip-up brim; one-size fits all.'),
#  (11, Decimal('1211'), 'en', 'Unisex long-sleeve AWC logo microfiber cycling jersey'),
#  (33, Decimal('1212'), 'en', 'Universal fit, well-vented, lightweight , snap-on visor.'),
#  (107, Decimal('1213'), 'en', 'Versatile 70 oz hydration pack offers extra storage, easy-fill access, and a waist belt.'),
#  (38, Decimal('1214'), 'en', 'Warm spandex tights for winter riding; seamless chamois construction eliminates pressure points.'),
#  (119, Decimal('1215'), 'en', 'Washes off the toughest road grime; dissolves grease, environmentally safe. 1-liter bottle.'),
#  (115, Decimal('1216'), 'en', 'Wraps to fit front and rear tires, carrier and 2 keys included.'),
#  (123, Decimal('1981'), 'en', 'Replacement mountain wheel for entry-level rider.'),
#  (124, Decimal('1987'), 'en', 'Replacement mountain wheel for the casual to serious rider.'),
#  (125, Decimal('1993'), 'en', 'High-performance mountain replacement wheel.'),
#  (126, Decimal('1999'), 'en', 'Replacement road rear wheel for entry-level cyclist.'),
#  (127, Decimal('2005'), 'en', 'Wide-link design.')]

# %% [markdown]
# Here we have a table for productid and product model with their description

# %%
# %%sql
#
# SELECT productid, PM.productmodelid, PM.productdescriptionid, PM.cultureid, description
# FROM productmodelproductdescriptionculture AS PM
#     JOIN productdescription PD ON PM.productdescriptionid = PD.productdescriptionid
#     JOIN product P ON  PM.productmodelid=P.productmodelid
#
#     WHERE PM.cultureid LIKE 'en';
# Out:
#  * postgresql://ec3_user:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/adventuretime
# 294 rows affected.
# [(680, 6, Decimal('1090'), 'en', 'Our lightest and best quality aluminum frame made from the newest alloy; it is welded and heat-treated for strength. Our innovative design results in maximum comfort and performance.'),
#  (706, 6, Decimal('1090'), 'en', 'Our lightest and best quality aluminum frame made from the newest alloy; it is welded and heat-treated for strength. Our innovative design results in maximum comfort and performance.'),
#  (707, 33, Decimal('1212'), 'en', 'Universal fit, well-vented, lightweight , snap-on visor.'),
#  (708, 33, Decimal('1212'), 'en', 'Universal fit, well-vented, lightweight , snap-on visor.'),
#  (709, 18, Decimal('1189'), 'en', 'Combination of natural and synthetic fibers stays dry and provides just the right cushioning.'),
#  (710, 18, Decimal('1189'), 'en', 'Combination of natural and synthetic fibers stays dry and provides just the right cushioning.'),
#  (711, 33, Decimal('1212'), 'en', 'Universal fit, well-vented, lightweight , snap-on visor.'),
#  (712, 2, Decimal('1210'), 'en', 'Traditional style with a flip-up brim; one-size fits all.'),
#  (713, 11, Decimal('1211'), 'en', 'Unisex long-sleeve AWC logo microfiber cycling jersey'),
#  (714, 11, Decimal('1211'), 'en', 'Unisex long-sleeve AWC logo microfiber cycling jersey'),
#  (715, 11, Decimal('1211'), 'en', 'Unisex long-sleeve AWC logo microfiber cycling jersey'),
#  (716, 11, Decimal('1211'), 'en', 'Unisex long-sleeve AWC logo microfiber cycling jersey'),
#  (717, 6, Decimal('1090'), 'en', 'Our lightest and best quality aluminum frame made from the newest alloy; it is welded and heat-treated for strength. Our innovative design results in maximum comfort and performance.'),
#  (718, 6, Decimal('1090'), 'en', 'Our lightest and best quality aluminum frame made from the newest alloy; it is welded and heat-treated for strength. Our innovative design results in maximum comfort and performance.'),
#  (719, 6, Decimal('1090'), 'en', 'Our lightest and best quality aluminum frame made from the newest alloy; it is welded and heat-treated for strength. Our innovative design results in maximum comfort and performance.'),
#  (720, 6, Decimal('1090'), 'en', 'Our lightest and best quality aluminum frame made from the newest alloy; it is welded and heat-treated for strength. Our innovative design results in maximum comfort and performance.'),
#  (721, 6, Decimal('1090'), 'en', 'Our lightest and best quality aluminum frame made from the newest alloy; it is welded and heat-treated for strength. Our innovative design results in maximum comfort and performance.'),
#  (722, 9, Decimal('1020'), 'en', 'The LL Frame provides a safe comfortable ride, while offering superior bump absorption in a value-priced aluminum frame.'),
#  (723, 9, Decimal('1020'), 'en', 'The LL Frame provides a safe comfortable ride, while offering superior bump absorption in a value-priced aluminum frame.'),
#  (724, 9, Decimal('1020'), 'en', 'The LL Frame provides a safe comfortable ride, while offering superior bump absorption in a value-priced aluminum frame.'),
#  (725, 9, Decimal('1020'), 'en', 'The LL Frame provides a safe comfortable ride, while offering superior bump absorption in a value-priced aluminum frame.'),
#  (726, 9, Decimal('1020'), 'en', 'The LL Frame provides a safe comfortable ride, while offering superior bump absorption in a value-priced aluminum frame.'),
#  (727, 9, Decimal('1020'), 'en', 'The LL Frame provides a safe comfortable ride, while offering superior bump absorption in a value-priced aluminum frame.'),
#  (728, 9, Decimal('1020'), 'en', 'The LL Frame provides a safe comfortable ride, while offering superior bump absorption in a value-priced aluminum frame.'),
#  (729, 9, Decimal('1020'), 'en', 'The LL Frame provides a safe comfortable ride, while offering superior bump absorption in a value-priced aluminum frame.'),
#  (730, 9, Decimal('1020'), 'en', 'The LL Frame provides a safe comfortable ride, while offering superior bump absorption in a value-priced aluminum frame.'),
#  (731, 16, Decimal('1062'), 'en', "Made from the same aluminum alloy as our top-of-the line HL frame, the ML features a lightweight down-tube milled to the perfect diameter for optimal strength. Men's version."),
#  (732, 16, Decimal('1062'), 'en', "Made from the same aluminum alloy as our top-of-the line HL frame, the ML features a lightweight down-tube milled to the perfect diameter for optimal strength. Men's version."),
#  (733, 16, Decimal('1062'), 'en', "Made from the same aluminum alloy as our top-of-the line HL frame, the ML features a lightweight down-tube milled to the perfect diameter for optimal strength. Men's version."),
#  (734, 16, Decimal('1062'), 'en', "Made from the same aluminum alloy as our top-of-the line HL frame, the ML features a lightweight down-tube milled to the perfect diameter for optimal strength. Men's version."),
#  (735, 16, Decimal('1062'), 'en', "Made from the same aluminum alloy as our top-of-the line HL frame, the ML features a lightweight down-tube milled to the perfect diameter for optimal strength. Men's version."),
#  (736, 9, Decimal('1020'), 'en', 'The LL Frame provides a safe comfortable ride, while offering superior bump absorption in a value-priced aluminum frame.'),
#  (737, 9, Decimal('1020'), 'en', 'The LL Frame provides a safe comfortable ride, while offering superior bump absorption in a value-priced aluminum frame.'),
#  (738, 9, Decimal('1020'), 'en', 'The LL Frame provides a safe comfortable ride, while offering superior bump absorption in a value-priced aluminum frame.'),
#  (739, 5, Decimal('647'), 'en', 'Each frame is hand-crafted in our Bothell facility to the optimum diameter and wall-thickness required of a premium mountain frame. The heat-treated welded aluminum frame has a larger diameter tube that absorbs the bumps.'),
#  (740, 5, Decimal('647'), 'en', 'Each frame is hand-crafted in our Bothell facility to the optimum diameter and wall-thickness required of a premium mountain frame. The heat-treated welded aluminum frame has a larger diameter tube that absorbs the bumps.'),
#  (741, 5, Decimal('647'), 'en', 'Each frame is hand-crafted in our Bothell facility to the optimum diameter and wall-thickness required of a premium mountain frame. The heat-treated welded aluminum frame has a larger diameter tube that absorbs the bumps.'),
#  (742, 5, Decimal('647'), 'en', 'Each frame is hand-crafted in our Bothell facility to the optimum diameter and wall-thickness required of a premium mountain frame. The heat-treated welded aluminum frame has a larger diameter tube that absorbs the bumps.'),
#  (743, 5, Decimal('647'), 'en', 'Each frame is hand-crafted in our Bothell facility to the optimum diameter and wall-thickness required of a premium mountain frame. The heat-treated welded aluminum frame has a larger diameter tube that absorbs the bumps.'),
#  (744, 5, Decimal('647'), 'en', 'Each frame is hand-crafted in our Bothell facility to the optimum diameter and wall-thickness required of a premium mountain frame. The heat-treated welded aluminum frame has a larger diameter tube that absorbs the bumps.'),
#  (745, 5, Decimal('647'), 'en', 'Each frame is hand-crafted in our Bothell facility to the optimum diameter and wall-thickness required of a premium mountain frame. The heat-treated welded aluminum frame has a larger diameter tube that absorbs the bumps.'),
#  (746, 5, Decimal('647'), 'en', 'Each frame is hand-crafted in our Bothell facility to the optimum diameter and wall-thickness required of a premium mountain frame. The heat-treated welded aluminum frame has a larger diameter tube that absorbs the bumps.'),
#  (747, 5, Decimal('647'), 'en', 'Each frame is hand-crafted in our Bothell facility to the optimum diameter and wall-thickness required of a premium mountain frame. The heat-treated welded aluminum frame has a larger diameter tube that absorbs the bumps.'),
#  (748, 5, Decimal('647'), 'en', 'Each frame is hand-crafted in our Bothell facility to the optimum diameter and wall-thickness required of a premium mountain frame. The heat-treated welded aluminum frame has a larger diameter tube that absorbs the bumps.'),
#  (749, 25, Decimal('457'), 'en', 'This bike is ridden by race winners. Developed with the Adventure Works Cycles professional race team, it has a extremely light heat-treated aluminum frame, and steering that allows precision control.'),
#  (750, 25, Decimal('457'), 'en', 'This bike is ridden by race winners. Developed with the Adventure Works Cycles professional race team, it has a extremely light heat-treated aluminum frame, and steering that allows precision control.'),
#  (751, 25, Decimal('457'), 'en', 'This bike is ridden by race winners. Developed with the Adventure Works Cycles professional race team, it has a extremely light heat-treated aluminum frame, and steering that allows precision control.'),
#  (752, 25, Decimal('457'), 'en', 'This bike is ridden by race winners. Developed with the Adventure Works Cycles professional race team, it has a extremely light heat-treated aluminum frame, and steering that allows precision control.'),
#  (753, 25, Decimal('457'), 'en', 'This bike is ridden by race winners. Developed with the Adventure Works Cycles professional race team, it has a extremely light heat-treated aluminum frame, and steering that allows precision control.'),
#  (754, 28, Decimal('337'), 'en', 'A true multi-sport bike that offers streamlined riding and a revolutionary design. Aerodynamic design lets you ride with the pros, and the gearing will conquer hilly roads.'),
#  (755, 28, Decimal('337'), 'en', 'A true multi-sport bike that offers streamlined riding and a revolutionary design. Aerodynamic design lets you ride with the pros, and the gearing will conquer hilly roads.'),
#  (756, 28, Decimal('337'), 'en', 'A true multi-sport bike that offers streamlined riding and a revolutionary design. Aerodynamic design lets you ride with the pros, and the gearing will conquer hilly roads.'),
#  (757, 28, Decimal('337'), 'en', 'A true multi-sport bike that offers streamlined riding and a revolutionary design. Aerodynamic design lets you ride with the pros, and the gearing will conquer hilly roads.'),
#  (758, 28, Decimal('337'), 'en', 'A true multi-sport bike that offers streamlined riding and a revolutionary design. Aerodynamic design lets you ride with the pros, and the gearing will conquer hilly roads.'),
#  (759, 30, Decimal('249'), 'en', "Value-priced bike with many features of our top-of-the-line models. Has the same light, stiff frame, and the quick acceleration we're famous for."),
#  (760, 30, Decimal('249'), 'en', "Value-priced bike with many features of our top-of-the-line models. Has the same light, stiff frame, and the quick acceleration we're famous for."),
#  (761, 30, Decimal('249'), 'en', "Value-priced bike with many features of our top-of-the-line models. Has the same light, stiff frame, and the quick acceleration we're famous for."),
#  (762, 30, Decimal('249'), 'en', "Value-priced bike with many features of our top-of-the-line models. Has the same light, stiff frame, and the quick acceleration we're famous for."),
#  (763, 30, Decimal('249'), 'en', "Value-priced bike with many features of our top-of-the-line models. Has the same light, stiff frame, and the quick acceleration we're famous for."),
#  (764, 30, Decimal('249'), 'en', "Value-priced bike with many features of our top-of-the-line models. Has the same light, stiff frame, and the quick acceleration we're famous for."),
#  (765, 30, Decimal('249'), 'en', "Value-priced bike with many features of our top-of-the-line models. Has the same light, stiff frame, and the quick acceleration we're famous for."),
#  (766, 30, Decimal('249'), 'en', "Value-priced bike with many features of our top-of-the-line models. Has the same light, stiff frame, and the quick acceleration we're famous for."),
#  (767, 30, Decimal('249'), 'en', "Value-priced bike with many features of our top-of-the-line models. Has the same light, stiff frame, and the quick acceleration we're famous for."),
#  (768, 30, Decimal('249'), 'en', "Value-priced bike with many features of our top-of-the-line models. Has the same light, stiff frame, and the quick acceleration we're famous for."),
#  (769, 30, Decimal('249'), 'en', "Value-priced bike with many features of our top-of-the-line models. Has the same light, stiff frame, and the quick acceleration we're famous for."),
#  (770, 30, Decimal('249'), 'en', "Value-priced bike with many features of our top-of-the-line models. Has the same light, stiff frame, and the quick acceleration we're famous for."),
#  (771, 19, Decimal('168'), 'en', 'Top-of-the-line competition mountain bike. Performance-enhancing options include the innovative HL Frame, super-smooth front suspension, and traction for all terrain.'),
#  (772, 19, Decimal('168'), 'en', 'Top-of-the-line competition mountain bike. Performance-enhancing options include the innovative HL Frame, super-smooth front suspension, and traction for all terrain.'),
#  (773, 19, Decimal('168'), 'en', 'Top-of-the-line competition mountain bike. Performance-enhancing options include the innovative HL Frame, super-smooth front suspension, and traction for all terrain.'),
#  (774, 19, Decimal('168'), 'en', 'Top-of-the-line competition mountain bike. Performance-enhancing options include the innovative HL Frame, super-smooth front suspension, and traction for all terrain.'),
#  (775, 19, Decimal('168'), 'en', 'Top-of-the-line competition mountain bike. Performance-enhancing options include the innovative HL Frame, super-smooth front suspension, and traction for all terrain.'),
#  (776, 19, Decimal('168'), 'en', 'Top-of-the-line competition mountain bike. Performance-enhancing options include the innovative HL Frame, super-smooth front suspension, and traction for all terrain.'),
#  (777, 19, Decimal('168'), 'en', 'Top-of-the-line competition mountain bike. Performance-enhancing options include the innovative HL Frame, super-smooth front suspension, and traction for all terrain.'),
#  (778, 19, Decimal('168'), 'en', 'Top-of-the-line competition mountain bike. Performance-enhancing options include the innovative HL Frame, super-smooth front suspension, and traction for all terrain.'),
#  (779, 20, Decimal('128'), 'en', 'Serious back-country riding. Perfect for all levels of competition. Uses the same HL Frame as the Mountain-100.'),
#  (780, 20, Decimal('128'), 'en', 'Serious back-country riding. Perfect for all levels of competition. Uses the same HL Frame as the Mountain-100.'),
#  (781, 20, Decimal('128'), 'en', 'Serious back-country riding. Perfect for all levels of competition. Uses the same HL Frame as the Mountain-100.'),
#  (782, 20, Decimal('128'), 'en', 'Serious back-country riding. Perfect for all levels of competition. Uses the same HL Frame as the Mountain-100.'),
#  (783, 20, Decimal('128'), 'en', 'Serious back-country riding. Perfect for all levels of competition. Uses the same HL Frame as the Mountain-100.'),
#  (784, 20, Decimal('128'), 'en', 'Serious back-country riding. Perfect for all levels of competition. Uses the same HL Frame as the Mountain-100.'),
#  (785, 21, Decimal('88'), 'en', 'For true trail addicts.  An extremely durable bike that will go anywhere and keep you in control on challenging terrain - without breaking your budget.'),
#  (786, 21, Decimal('88'), 'en', 'For true trail addicts.  An extremely durable bike that will go anywhere and keep you in control on challenging terrain - without breaking your budget.'),
#  (787, 21, Decimal('88'), 'en', 'For true trail addicts.  An extremely durable bike that will go anywhere and keep you in control on challenging terrain - without breaking your budget.'),
#  (788, 21, Decimal('88'), 'en', 'For true trail addicts.  An extremely durable bike that will go anywhere and keep you in control on challenging terrain - without breaking your budget.'),
#  (789, 26, Decimal('409'), 'en', 'Alluminum-alloy frame provides a light, stiff ride, whether you are racing in the velodrome or on a demanding club ride on country roads.'),
#  (790, 26, Decimal('409'), 'en', 'Alluminum-alloy frame provides a light, stiff ride, whether you are racing in the velodrome or on a demanding club ride on country roads.'),
#  (791, 26, Decimal('409'), 'en', 'Alluminum-alloy frame provides a light, stiff ride, whether you are racing in the velodrome or on a demanding club ride on country roads.'),
#  (792, 26, Decimal('409'), 'en', 'Alluminum-alloy frame provides a light, stiff ride, whether you are racing in the velodrome or on a demanding club ride on country roads.'),
#  (793, 26, Decimal('409'), 'en', 'Alluminum-alloy frame provides a light, stiff ride, whether you are racing in the velodrome or on a demanding club ride on country roads.'),
#  (794, 26, Decimal('409'), 'en', 'Alluminum-alloy frame provides a light, stiff ride, whether you are racing in the velodrome or on a demanding club ride on country roads.'),
#  (795, 26, Decimal('409'), 'en', 'Alluminum-alloy frame provides a light, stiff ride, whether you are racing in the velodrome or on a demanding club ride on country roads.'),
#  (796, 26, Decimal('409'), 'en', 'Alluminum-alloy frame provides a light, stiff ride, whether you are racing in the velodrome or on a demanding club ride on country roads.'),
#  (797, 29, Decimal('320'), 'en', 'Same technology as all of our Road series bikes, but the frame is sized for a woman.  Perfect all-around bike for road or racing.'),
#  (798, 29, Decimal('320'), 'en', 'Same technology as all of our Road series bikes, but the frame is sized for a woman.  Perfect all-around bike for road or racing.'),
#  (799, 29, Decimal('320'), 'en', 'Same technology as all of our Road series bikes, but the frame is sized for a woman.  Perfect all-around bike for road or racing.'),
#  (800, 29, Decimal('320'), 'en', 'Same technology as all of our Road series bikes, but the frame is sized for a woman.  Perfect all-around bike for road or racing.'),
#  (801, 29, Decimal('320'), 'en', 'Same technology as all of our Road series bikes, but the frame is sized for a woman.  Perfect all-around bike for road or racing.'),
#  (802, 104, Decimal('633'), 'en', 'Stout design absorbs shock and offers more precise steering.'),
#  (803, 105, Decimal('634'), 'en', 'Composite road fork with an aluminum steerer tube.'),
#  (804, 106, Decimal('635'), 'en', 'High-performance carbon road fork with curved legs.'),
#  (805, 59, Decimal('744'), 'en', 'Threadless headset provides quality at an economical price.'),
#  (806, 60, Decimal('745'), 'en', 'Sealed cartridge keeps dirt out.'),
#  (807, 61, Decimal('746'), 'en', 'High-quality 1 threadless headset with a grease port for quick lubrication.'),
#  (808, 52, Decimal('697'), 'en', 'All-purpose bar for on or off-road.'),
#  (809, 54, Decimal('698'), 'en', 'Tough aluminum alloy bars for downhill.'),
#  (810, 55, Decimal('699'), 'en', 'Flat bar strong enough for the pro circuit.'),
#  (811, 56, Decimal('700'), 'en', 'Unique shape provides easier reach to the levers.'),
#  (812, 57, Decimal('701'), 'en', 'Anatomically shaped aluminum tube bar will suit all riders.'),
#  (813, 58, Decimal('702'), 'en', 'Designed for racers; high-end anatomically shaped bar from aluminum alloy.'),
#  (814, 15, Decimal('642'), 'en', "The ML frame is a heat-treated aluminum frame made with the same detail and quality as our HL frame. It offers superior performance. Men's version."),
#  (815, 42, Decimal('686'), 'en', 'Replacement mountain wheel for entry-level rider.'),
#  (816, 45, Decimal('687'), 'en', 'Replacement mountain wheel for the casual to serious rider.'),
#  (817, 46, Decimal('688'), 'en', 'High-performance mountain replacement wheel.'),
#  (818, 49, Decimal('689'), 'en', 'Replacement road front wheel for entry-level cyclist.'),
#  (819, 50, Decimal('690'), 'en', 'Sturdy alloy features a quick-release hub.'),
#  (820, 51, Decimal('691'), 'en', 'Strong wheel with double-walled rim.'),
#  (821, 44, Decimal('692'), 'en', 'Aerodynamic rims for smooth riding.'),
#  (822, 17, Decimal('661'), 'en', "Made from the same aluminum alloy as our top-of-the line HL frame, the ML features a lightweight down-tube milled to the perfect diameter for optimal strength. Women's version."),
#  (823, 123, Decimal('1981'), 'en', 'Replacement mountain wheel for entry-level rider.'),
#  (824, 124, Decimal('1987'), 'en', 'Replacement mountain wheel for the casual to serious rider.'),
#  (825, 125, Decimal('1993'), 'en', 'High-performance mountain replacement wheel.'),
#  (826, 126, Decimal('1999'), 'en', 'Replacement road rear wheel for entry-level cyclist.'),
#  (827, 77, Decimal('871'), 'en', 'Aluminum alloy rim with stainless steel spokes; built for speed.'),
#  (828, 78, Decimal('872'), 'en', 'Strong rear wheel with double-walled rim.'),
#  (829, 43, Decimal('873'), 'en', 'Excellent aerodynamic rims guarantee a smooth ride.'),
#  (872, 113, Decimal('1185'), 'en', 'Aluminum cage is lighter than our mountain version; perfect for long distance trips.'),
#  (830, 14, Decimal('644'), 'en', "The ML frame is a heat-treated aluminum frame made with the same detail and quality as our HL frame. It offers superior performance. Women's version."),
#  (831, 14, Decimal('644'), 'en', "The ML frame is a heat-treated aluminum frame made with the same detail and quality as our HL frame. It offers superior performance. Women's version."),
#  (832, 14, Decimal('644'), 'en', "The ML frame is a heat-treated aluminum frame made with the same detail and quality as our HL frame. It offers superior performance. Women's version."),
#  (833, 17, Decimal('661'), 'en', "Made from the same aluminum alloy as our top-of-the line HL frame, the ML features a lightweight down-tube milled to the perfect diameter for optimal strength. Women's version."),
#  (834, 17, Decimal('661'), 'en', "Made from the same aluminum alloy as our top-of-the line HL frame, the ML features a lightweight down-tube milled to the perfect diameter for optimal strength. Women's version."),
#  (835, 17, Decimal('661'), 'en', "Made from the same aluminum alloy as our top-of-the line HL frame, the ML features a lightweight down-tube milled to the perfect diameter for optimal strength. Women's version."),
#  (836, 17, Decimal('661'), 'en', "Made from the same aluminum alloy as our top-of-the line HL frame, the ML features a lightweight down-tube milled to the perfect diameter for optimal strength. Women's version."),
#  (837, 6, Decimal('1090'), 'en', 'Our lightest and best quality aluminum frame made from the newest alloy; it is welded and heat-treated for strength. Our innovative design results in maximum comfort and performance.'),
#  (838, 6, Decimal('1090'), 'en', 'Our lightest and best quality aluminum frame made from the newest alloy; it is welded and heat-treated for strength. Our innovative design results in maximum comfort and performance.'),
#  (839, 6, Decimal('1090'), 'en', 'Our lightest and best quality aluminum frame made from the newest alloy; it is welded and heat-treated for strength. Our innovative design results in maximum comfort and performance.'),
#  (840, 6, Decimal('1090'), 'en', 'Our lightest and best quality aluminum frame made from the newest alloy; it is welded and heat-treated for strength. Our innovative design results in maximum comfort and performance.'),
#  (841, 13, Decimal('1200'), 'en', "Men's 8-panel racing shorts - lycra with an elastic waistband and leg grippers."),
#  (842, 120, Decimal('1193'), 'en', 'Durable, water-proof nylon construction with easy access. Large enough for weekend trips.'),
#  (843, 115, Decimal('1216'), 'en', 'Wraps to fit front and rear tires, carrier and 2 keys included.'),
#  (844, 116, Decimal('1191'), 'en', 'Designed for convenience. Fits in your pocket. Aluminum barrel. 160psi rated.'),
#  (845, 117, Decimal('1206'), 'en', 'Simple and light-weight. Emergency patches stored in handle.'),
#  (846, 108, Decimal('1183'), 'en', 'Affordable light for safe night riding - uses 3 AAA batteries'),
#  (847, 109, Decimal('1202'), 'en', 'Rechargeable dual-beam headlight.'),
#  (848, 110, Decimal('1203'), 'en', 'Rugged weatherproof headlight.'),
#  (849, 13, Decimal('1200'), 'en', "Men's 8-panel racing shorts - lycra with an elastic waistband and leg grippers."),
#  (850, 13, Decimal('1200'), 'en', "Men's 8-panel racing shorts - lycra with an elastic waistband and leg grippers."),
#  (851, 13, Decimal('1200'), 'en', "Men's 8-panel racing shorts - lycra with an elastic waistband and leg grippers."),
#  (852, 38, Decimal('1214'), 'en', 'Warm spandex tights for winter riding; seamless chamois construction eliminates pressure points.'),
#  (853, 38, Decimal('1214'), 'en', 'Warm spandex tights for winter riding; seamless chamois construction eliminates pressure points.'),
#  (854, 38, Decimal('1214'), 'en', 'Warm spandex tights for winter riding; seamless chamois construction eliminates pressure points.'),
#  (855, 12, Decimal('1192'), 'en', 'Designed for the AWC team with stay-put straps, moisture-control, chamois padding, and leg grippers.'),
#  (856, 12, Decimal('1192'), 'en', 'Designed for the AWC team with stay-put straps, moisture-control, chamois padding, and leg grippers.'),
#  (857, 12, Decimal('1192'), 'en', 'Designed for the AWC team with stay-put straps, moisture-control, chamois padding, and leg grippers.'),
#  (858, 4, Decimal('1194'), 'en', 'Full padding, improved finger flex, durable palm, adjustable closure.'),
#  (859, 4, Decimal('1194'), 'en', 'Full padding, improved finger flex, durable palm, adjustable closure.'),
#  (860, 4, Decimal('1194'), 'en', 'Full padding, improved finger flex, durable palm, adjustable closure.'),
#  (861, 3, Decimal('1195'), 'en', 'Synthetic palm, flexible knuckles, breathable mesh upper. Worn by the AWC team riders.'),
#  (862, 3, Decimal('1195'), 'en', 'Synthetic palm, flexible knuckles, breathable mesh upper. Worn by the AWC team riders.'),
#  (863, 3, Decimal('1195'), 'en', 'Synthetic palm, flexible knuckles, breathable mesh upper. Worn by the AWC team riders.'),
#  (864, 1, Decimal('1199'), 'en', 'Light-weight, wind-resistant, packs to fit into a pocket.'),
#  (865, 1, Decimal('1199'), 'en', 'Light-weight, wind-resistant, packs to fit into a pocket.'),
#  (866, 1, Decimal('1199'), 'en', 'Light-weight, wind-resistant, packs to fit into a pocket.'),
#  (867, 37, Decimal('1196'), 'en', 'Heavy duty, abrasion-resistant shorts feature seamless, lycra inner shorts with anti-bacterial chamois for comfort.'),
#  (868, 37, Decimal('1196'), 'en', 'Heavy duty, abrasion-resistant shorts feature seamless, lycra inner shorts with anti-bacterial chamois for comfort.'),
#  (869, 37, Decimal('1196'), 'en', 'Heavy duty, abrasion-resistant shorts feature seamless, lycra inner shorts with anti-bacterial chamois for comfort.'),
#  (870, 111, Decimal('1186'), 'en', 'AWC logo water bottle - holds 30 oz; leak-proof.'),
#  (871, 112, Decimal('1209'), 'en', 'Tough aluminum cage holds bottle securly on tough terrain.'),
#  (873, 114, Decimal('1197'), 'en', 'Includes 8 different size patches, glue and sandpaper.'),
#  (874, 24, Decimal('1208'), 'en', 'Thin, lightweight and durable with cuffs that stay up.'),
#  (875, 24, Decimal('1208'), 'en', 'Thin, lightweight and durable with cuffs that stay up.'),
#  (876, 118, Decimal('1187'), 'en', 'Carries 4 bikes securely; steel construction, fits 2 receiver hitch.'),
#  (877, 119, Decimal('1215'), 'en', 'Washes off the toughest road grime; dissolves grease, environmentally safe. 1-liter bottle.'),
#  (878, 121, Decimal('1188'), 'en', 'Clip-on fenders fit most mountain bikes.'),
#  (879, 122, Decimal('1201'), 'en', 'Perfect all-purpose bike stand for working on your bike at home. Quick-adjusting clamps and steel construction.'),
#  (880, 107, Decimal('1213'), 'en', 'Versatile 70 oz hydration pack offers extra storage, easy-fill access, and a waist belt.'),
#  (881, 32, Decimal('1205'), 'en', 'Short sleeve classic breathable jersey with superior moisture control, front zipper, and 3 back pockets.'),
#  (882, 32, Decimal('1205'), 'en', 'Short sleeve classic breathable jersey with superior moisture control, front zipper, and 3 back pockets.'),
#  (883, 32, Decimal('1205'), 'en', 'Short sleeve classic breathable jersey with superior moisture control, front zipper, and 3 back pockets.'),
#  (884, 32, Decimal('1205'), 'en', 'Short sleeve classic breathable jersey with superior moisture control, front zipper, and 3 back pockets.'),
#  (885, 7, Decimal('1182'), 'en', "The HL aluminum frame is custom-shaped for both good looks and strength; it will withstand the most rigorous challenges of daily riding. Men's version."),
#  (886, 10, Decimal('1146'), 'en', 'Lightweight butted aluminum frame provides a more upright riding position for a trip around town.  Our ground-breaking design provides optimum comfort.'),
#  (887, 7, Decimal('1182'), 'en', "The HL aluminum frame is custom-shaped for both good looks and strength; it will withstand the most rigorous challenges of daily riding. Men's version."),
#  (888, 7, Decimal('1182'), 'en', "The HL aluminum frame is custom-shaped for both good looks and strength; it will withstand the most rigorous challenges of daily riding. Men's version."),
#  (889, 7, Decimal('1182'), 'en', "The HL aluminum frame is custom-shaped for both good looks and strength; it will withstand the most rigorous challenges of daily riding. Men's version."),
#  (890, 7, Decimal('1182'), 'en', "The HL aluminum frame is custom-shaped for both good looks and strength; it will withstand the most rigorous challenges of daily riding. Men's version."),
#  (891, 7, Decimal('1182'), 'en', "The HL aluminum frame is custom-shaped for both good looks and strength; it will withstand the most rigorous challenges of daily riding. Men's version."),
#  (892, 7, Decimal('1182'), 'en', "The HL aluminum frame is custom-shaped for both good looks and strength; it will withstand the most rigorous challenges of daily riding. Men's version."),
#  (893, 7, Decimal('1182'), 'en', "The HL aluminum frame is custom-shaped for both good looks and strength; it will withstand the most rigorous challenges of daily riding. Men's version."),
#  (894, 127, Decimal('2005'), 'en', 'Wide-link design.'),
#  (895, 10, Decimal('1146'), 'en', 'Lightweight butted aluminum frame provides a more upright riding position for a trip around town.  Our ground-breaking design provides optimum comfort.'),
#  (896, 10, Decimal('1146'), 'en', 'Lightweight butted aluminum frame provides a more upright riding position for a trip around town.  Our ground-breaking design provides optimum comfort.'),
#  (897, 10, Decimal('1146'), 'en', 'Lightweight butted aluminum frame provides a more upright riding position for a trip around town.  Our ground-breaking design provides optimum comfort.'),
#  (898, 10, Decimal('1146'), 'en', 'Lightweight butted aluminum frame provides a more upright riding position for a trip around town.  Our ground-breaking design provides optimum comfort.'),
#  (899, 10, Decimal('1146'), 'en', 'Lightweight butted aluminum frame provides a more upright riding position for a trip around town.  Our ground-breaking design provides optimum comfort.'),
#  (900, 10, Decimal('1146'), 'en', 'Lightweight butted aluminum frame provides a more upright riding position for a trip around town.  Our ground-breaking design provides optimum comfort.'),
#  (901, 10, Decimal('1146'), 'en', 'Lightweight butted aluminum frame provides a more upright riding position for a trip around town.  Our ground-breaking design provides optimum comfort.'),
#  (902, 10, Decimal('1146'), 'en', 'Lightweight butted aluminum frame provides a more upright riding position for a trip around town.  Our ground-breaking design provides optimum comfort.'),
#  (903, 10, Decimal('1146'), 'en', 'Lightweight butted aluminum frame provides a more upright riding position for a trip around town.  Our ground-breaking design provides optimum comfort.'),
#  (904, 15, Decimal('642'), 'en', "The ML frame is a heat-treated aluminum frame made with the same detail and quality as our HL frame. It offers superior performance. Men's version."),
#  (905, 15, Decimal('642'), 'en', "The ML frame is a heat-treated aluminum frame made with the same detail and quality as our HL frame. It offers superior performance. Men's version."),
#  (906, 15, Decimal('642'), 'en', "The ML frame is a heat-treated aluminum frame made with the same detail and quality as our HL frame. It offers superior performance. Men's version."),
#  (908, 79, Decimal('885'), 'en', 'Synthetic leather. Features gel for increased comfort.'),
#  (909, 80, Decimal('886'), 'en', 'Designed to absorb shock.'),
#  (910, 81, Decimal('887'), 'en', 'Anatomic design for a full-day of riding in comfort. Durable leather.'),
#  (911, 82, Decimal('888'), 'en', 'Lightweight foam-padded saddle.'),
#  (912, 83, Decimal('889'), 'en', 'Rubber bumpers absorb bumps.'),
#  (913, 84, Decimal('890'), 'en', 'Lightweight kevlar racing saddle. Leather.'),
#  (914, 66, Decimal('891'), 'en', 'Comfortable, ergonomically shaped gel saddle.'),
#  (915, 65, Decimal('892'), 'en', 'New design relieves pressure for long rides.'),
#  (916, 67, Decimal('893'), 'en', 'Cut-out shell for a more comfortable ride.'),
#  (917, 8, Decimal('637'), 'en', 'Our best value utilizing the same, ground-breaking frame technology as the ML aluminum frame.'),
#  (918, 8, Decimal('637'), 'en', 'Our best value utilizing the same, ground-breaking frame technology as the ML aluminum frame.'),
#  (919, 8, Decimal('637'), 'en', 'Our best value utilizing the same, ground-breaking frame technology as the ML aluminum frame.'),
#  (920, 8, Decimal('637'), 'en', 'Our best value utilizing the same, ground-breaking frame technology as the ML aluminum frame.'),
#  (921, 92, Decimal('912'), 'en', 'Self-sealing tube.'),
#  (922, 93, Decimal('913'), 'en', 'Conventional all-purpose tube.'),
#  (923, 94, Decimal('914'), 'en', 'General purpose tube.'),
#  (924, 8, Decimal('637'), 'en', 'Our best value utilizing the same, ground-breaking frame technology as the ML aluminum frame.'),
#  (925, 8, Decimal('637'), 'en', 'Our best value utilizing the same, ground-breaking frame technology as the ML aluminum frame.'),
#  (926, 8, Decimal('637'), 'en', 'Our best value utilizing the same, ground-breaking frame technology as the ML aluminum frame.'),
#  (927, 8, Decimal('637'), 'en', 'Our best value utilizing the same, ground-breaking frame technology as the ML aluminum frame.'),
#  (928, 85, Decimal('903'), 'en', 'Comparible traction, less expensive wire bead casing.'),
#  (929, 86, Decimal('904'), 'en', 'Great traction, high-density rubber.'),
#  (930, 87, Decimal('905'), 'en', 'Incredible traction, lightweight carbon reinforced.'),
#  (931, 88, Decimal('906'), 'en', 'Same great treads as more expensive tire with a less expensive wire bead casing.'),
#  (932, 89, Decimal('907'), 'en', 'Higher density rubber.'),
#  (933, 90, Decimal('908'), 'en', 'Lightweight carbon reinforced  for an unrivaled ride at an un-compromised weight.'),
#  (934, 91, Decimal('909'), 'en', 'High-density rubber.'),
#  (935, 62, Decimal('847'), 'en', 'Expanded platform so you can ride in any shoes; great for all-around riding.'),
#  (936, 63, Decimal('848'), 'en', 'Lightweight, durable, clipless pedal with adjustable tension.'),
#  (937, 64, Decimal('849'), 'en', 'Stainless steel; designed to shed mud easily.'),
#  (938, 68, Decimal('850'), 'en', 'Clipless pedals - aluminum.'),
#  (939, 69, Decimal('851'), 'en', 'Lightweight aluminum alloy construction.'),
#  (940, 70, Decimal('852'), 'en', 'Top-of-the-line clipless pedals with adjustable tension.'),
#  (941, 53, Decimal('853'), 'en', 'A stable pedal for all-day riding.'),
#  (942, 15, Decimal('642'), 'en', "The ML frame is a heat-treated aluminum frame made with the same detail and quality as our HL frame. It offers superior performance. Men's version."),
#  (943, 8, Decimal('637'), 'en', 'Our best value utilizing the same, ground-breaking frame technology as the ML aluminum frame.'),
#  (944, 8, Decimal('637'), 'en', 'Our best value utilizing the same, ground-breaking frame technology as the ML aluminum frame.'),
#  (945, 103, Decimal('630'), 'en', 'Wide-link design.'),
#  (946, 47, Decimal('703'), 'en', 'Unique shape reduces fatigue for entry level riders.'),
#  (947, 48, Decimal('704'), 'en', 'A light yet stiff aluminum bar for long distance riding.'),
#  (948, 102, Decimal('627'), 'en', 'All-weather brake pads; provides superior stopping by applying more surface to the rim.'),
#  (949, 99, Decimal('618'), 'en', 'Super rigid spindle.'),
#  (950, 100, Decimal('619'), 'en', 'High-strength crank arm.'),
#  (951, 101, Decimal('620'), 'en', 'Triple crankset; alumunim crank arm; flawless shifting.'),
#  (952, 98, Decimal('613'), 'en', 'Superior shifting performance.'),
#  (953, 35, Decimal('554'), 'en', "The plush custom saddle keeps you riding all day,  and there's plenty of space to add panniers and bike bags to the newly-redesigned carrier.  This bike has stability when fully-loaded."),
#  (954, 34, Decimal('594'), 'en', 'Travel in style and comfort. Designed for maximum comfort and safety. Wide gear range takes on all hills. High-tech aluminum alloy construction provides durability without added weight.'),
#  (955, 34, Decimal('594'), 'en', 'Travel in style and comfort. Designed for maximum comfort and safety. Wide gear range takes on all hills. High-tech aluminum alloy construction provides durability without added weight.'),
#  (956, 34, Decimal('594'), 'en', 'Travel in style and comfort. Designed for maximum comfort and safety. Wide gear range takes on all hills. High-tech aluminum alloy construction provides durability without added weight.'),
#  (957, 34, Decimal('594'), 'en', 'Travel in style and comfort. Designed for maximum comfort and safety. Wide gear range takes on all hills. High-tech aluminum alloy construction provides durability without added weight.'),
#  (958, 36, Decimal('513'), 'en', 'All-occasion value bike with our basic comfort and safety features. Offers wider, more stable tires for a ride around town or weekend trip.'),
#  (959, 36, Decimal('513'), 'en', 'All-occasion value bike with our basic comfort and safety features. Offers wider, more stable tires for a ride around town or weekend trip.'),
#  (960, 36, Decimal('513'), 'en', 'All-occasion value bike with our basic comfort and safety features. Offers wider, more stable tires for a ride around town or weekend trip.'),
#  (961, 36, Decimal('513'), 'en', 'All-occasion value bike with our basic comfort and safety features. Offers wider, more stable tires for a ride around town or weekend trip.'),
#  (962, 36, Decimal('513'), 'en', 'All-occasion value bike with our basic comfort and safety features. Offers wider, more stable tires for a ride around town or weekend trip.'),
#  (963, 36, Decimal('513'), 'en', 'All-occasion value bike with our basic comfort and safety features. Offers wider, more stable tires for a ride around town or weekend trip.'),
#  (964, 36, Decimal('513'), 'en', 'All-occasion value bike with our basic comfort and safety features. Offers wider, more stable tires for a ride around town or weekend trip.'),
#  (965, 36, Decimal('513'), 'en', 'All-occasion value bike with our basic comfort and safety features. Offers wider, more stable tires for a ride around town or weekend trip.'),
#  (966, 34, Decimal('594'), 'en', 'Travel in style and comfort. Designed for maximum comfort and safety. Wide gear range takes on all hills. High-tech aluminum alloy construction provides durability without added weight.'),
#  (967, 34, Decimal('594'), 'en', 'Travel in style and comfort. Designed for maximum comfort and safety. Wide gear range takes on all hills. High-tech aluminum alloy construction provides durability without added weight.'),
#  (968, 34, Decimal('594'), 'en', 'Travel in style and comfort. Designed for maximum comfort and safety. Wide gear range takes on all hills. High-tech aluminum alloy construction provides durability without added weight.'),
#  (969, 34, Decimal('594'), 'en', 'Travel in style and comfort. Designed for maximum comfort and safety. Wide gear range takes on all hills. High-tech aluminum alloy construction provides durability without added weight.'),
#  (970, 35, Decimal('554'), 'en', "The plush custom saddle keeps you riding all day,  and there's plenty of space to add panniers and bike bags to the newly-redesigned carrier.  This bike has stability when fully-loaded."),
#  (971, 35, Decimal('554'), 'en', "The plush custom saddle keeps you riding all day,  and there's plenty of space to add panniers and bike bags to the newly-redesigned carrier.  This bike has stability when fully-loaded."),
#  (972, 35, Decimal('554'), 'en', "The plush custom saddle keeps you riding all day,  and there's plenty of space to add panniers and bike bags to the newly-redesigned carrier.  This bike has stability when fully-loaded."),
#  (973, 27, Decimal('376'), 'en', 'Cross-train, race, or just socialize on a sleek, aerodynamic bike designed for a woman.  Advanced seat technology provides comfort all day.'),
#  (974, 27, Decimal('376'), 'en', 'Cross-train, race, or just socialize on a sleek, aerodynamic bike designed for a woman.  Advanced seat technology provides comfort all day.'),
#  (975, 27, Decimal('376'), 'en', 'Cross-train, race, or just socialize on a sleek, aerodynamic bike designed for a woman.  Advanced seat technology provides comfort all day.'),
#  (976, 27, Decimal('376'), 'en', 'Cross-train, race, or just socialize on a sleek, aerodynamic bike designed for a woman.  Advanced seat technology provides comfort all day.'),
#  (977, 31, Decimal('209'), 'en', 'Entry level adult bike; offers a comfortable ride cross-country or down the block. Quick-release hubs and rims.'),
#  (978, 36, Decimal('513'), 'en', 'All-occasion value bike with our basic comfort and safety features. Offers wider, more stable tires for a ride around town or weekend trip.'),
#  (979, 36, Decimal('513'), 'en', 'All-occasion value bike with our basic comfort and safety features. Offers wider, more stable tires for a ride around town or weekend trip.'),
#  (980, 22, Decimal('64'), 'en', 'This bike delivers a high-level of performance on a budget. It is responsive and maneuverable, and offers peace-of-mind when you decide to go off-road.'),
#  (981, 22, Decimal('64'), 'en', 'This bike delivers a high-level of performance on a budget. It is responsive and maneuverable, and offers peace-of-mind when you decide to go off-road.'),
#  (982, 22, Decimal('64'), 'en', 'This bike delivers a high-level of performance on a budget. It is responsive and maneuverable, and offers peace-of-mind when you decide to go off-road.'),
#  (983, 22, Decimal('64'), 'en', 'This bike delivers a high-level of performance on a budget. It is responsive and maneuverable, and offers peace-of-mind when you decide to go off-road.'),
#  (984, 23, Decimal('8'), 'en', 'Suitable for any type of riding, on or off-road. Fits any budget. Smooth-shifting with a comfortable ride.'),
#  (985, 23, Decimal('8'), 'en', 'Suitable for any type of riding, on or off-road. Fits any budget. Smooth-shifting with a comfortable ride.'),
#  (986, 23, Decimal('8'), 'en', 'Suitable for any type of riding, on or off-road. Fits any budget. Smooth-shifting with a comfortable ride.'),
#  (987, 23, Decimal('8'), 'en', 'Suitable for any type of riding, on or off-road. Fits any budget. Smooth-shifting with a comfortable ride.'),
#  (988, 23, Decimal('8'), 'en', 'Suitable for any type of riding, on or off-road. Fits any budget. Smooth-shifting with a comfortable ride.'),
#  (989, 23, Decimal('8'), 'en', 'Suitable for any type of riding, on or off-road. Fits any budget. Smooth-shifting with a comfortable ride.'),
#  (990, 23, Decimal('8'), 'en', 'Suitable for any type of riding, on or off-road. Fits any budget. Smooth-shifting with a comfortable ride.'),
#  (991, 23, Decimal('8'), 'en', 'Suitable for any type of riding, on or off-road. Fits any budget. Smooth-shifting with a comfortable ride.'),
#  (992, 23, Decimal('8'), 'en', 'Suitable for any type of riding, on or off-road. Fits any budget. Smooth-shifting with a comfortable ride.'),
#  (993, 23, Decimal('8'), 'en', 'Suitable for any type of riding, on or off-road. Fits any budget. Smooth-shifting with a comfortable ride.'),
#  (994, 95, Decimal('3'), 'en', 'Chromoly steel.'),
#  (995, 96, Decimal('4'), 'en', 'Aluminum alloy cups; large diameter spindle.'),
#  (996, 97, Decimal('5'), 'en', 'Aluminum alloy cups and a hollow axle.'),
#  (997, 31, Decimal('209'), 'en', 'Entry level adult bike; offers a comfortable ride cross-country or down the block. Quick-release hubs and rims.'),
#  (998, 31, Decimal('209'), 'en', 'Entry level adult bike; offers a comfortable ride cross-country or down the block. Quick-release hubs and rims.'),
#  (999, 31, Decimal('209'), 'en', 'Entry level adult bike; offers a comfortable ride cross-country or down the block. Quick-release hubs and rims.')]

# %% [markdown]
# The description for the product with reviews

# %%
# %%sql
# SELECT DISTINCT PR.productid, PM.productdescriptionid, PM.cultureid, description
# FROM productmodelproductdescriptionculture AS PM
#     JOIN productdescription PD ON PM.productdescriptionid = PD.productdescriptionid
#     JOIN product P ON  PM.productmodelid=P.productmodelid
#     JOIN productreview PR ON P.productid = PR.productid
# WHERE PM.cultureid LIKE 'en';
# Out:
#  * postgresql://ec3_user:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/adventuretime
# 3 rows affected.
# [(Decimal('937'), Decimal('849'), 'en', 'Stainless steel; designed to shed mud easily.'),
#  (Decimal('798'), Decimal('320'), 'en', 'Same technology as all of our Road series bikes, but the frame is sized for a woman.  Perfect all-around bike for road or racing.'),
#  (Decimal('709'), Decimal('1189'), 'en', 'Combination of natural and synthetic fibers stays dry and provides just the right cushioning.')]

# %% [markdown]
# ### Exercise 4:
#
# Since we cannot infer the most popular products from the reviews, we will go with an alternative strategy.
#
# Get the model ID, name, description, and total number of sales for each product and display the top-10 selling products. You can infer how often products have been sold by looking at the `salesorderdetail` table (each row might indicate more than one sale, so take note of `OrderQty`).

# %% [markdown]
# **Answer.**

# %%
# %%sql
# SELECT b.productid, productmodelid, description, totalsales
# FROM (SELECT productid, SUM(orderqty) AS TotalSales
#     FROM salesorderdetail
#     GROUP BY productid) a
# JOIN (
#     SELECT productid, PM.productmodelid, PM.productdescriptionid, PM.cultureid, description
#     FROM productmodelproductdescriptionculture AS PM
#         JOIN productdescription PD ON PM.productdescriptionid = PD.productdescriptionid
#         FULL JOIN product P ON  PM.productmodelid=P.productmodelid
#     WHERE PM.cultureid LIKE 'en'
#     )b ON a.productid = b.productid
# ORDER BY totalsales DESC
# LIMIT 10;
# Out:
#  * postgresql://ec3_user:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/adventuretime
# 10 rows affected.
# [(712, 2, 'Traditional style with a flip-up brim; one-size fits all.', 8311),
#  (870, 111, 'AWC logo water bottle - holds 30 oz; leak-proof.', 6815),
#  (711, 33, 'Universal fit, well-vented, lightweight , snap-on visor.', 6743),
#  (715, 11, 'Unisex long-sleeve AWC logo microfiber cycling jersey', 6592),
#  (708, 33, 'Universal fit, well-vented, lightweight , snap-on visor.', 6532),
#  (707, 33, 'Universal fit, well-vented, lightweight , snap-on visor.', 6266),
#  (864, 1, 'Light-weight, wind-resistant, packs to fit into a pocket.', 4247),
#  (873, 114, 'Includes 8 different size patches, glue and sandpaper.', 3865),
#  (884, 32, 'Short sleeve classic breathable jersey with superior moisture control, front zipper, and 3 back pockets.', 3864),
#  (714, 11, 'Unisex long-sleeve AWC logo microfiber cycling jersey', 3636)]

# %% [markdown]
# ---------

# %% [markdown]
# ### Exercise 5:
#
# Let's look at the correlation between quantity sold and price for each item in each subcategory. Some subcategories don't have enough sales to make the correlation meaningful, so only look at the top 10 subcategories by total quantity of sales.
#
# Once you've looked at the data, make a hypothesis about what causes any positive or negative correlations between price and quantity, and explain this in 2-3 sentences.
#
# **Hint:** You'll need to calculate the total quantities from `salesorderdetail` again and group the products by subcategory. It'll probably be easier if you use at least two [CTEs](https://www.postgresql.org/docs/9.1/queries-with.html). You can calculate the correlation in PostgreSQL by using the built-in [```corr()```](https://www.postgresql.org/docs/9.4/functions-aggregate.html) function.

# %% [markdown]
# **Answer.**

# %%
# %%sql
# WITH prov AS(
# SELECT productsubcategoryid, SUM(orderqty) totalquantity1, unitprice
# FROM salesorderdetail SO
# JOIN product P ON (SO.productid = P.productid)
# GROUP BY productsubcategoryid, unitprice
# ), topten AS (
#         SELECT productsubcategoryid, SUM(orderqty) as totalquantity2
#         FROM salesorderdetail SO
#         JOIN product P ON (SO.productid = P.productid)
#         GROUP BY productsubcategoryid
#         ORDER BY Totalquantity2 DESC
#         LIMIT 10
# )
#
# SELECT TT.productsubcategoryid,corr(unitprice,totalquantity1)
# FROM prov as PV
# JOIN topten TT ON(PV.productsubcategoryid=TT.productsubcategoryid)
# GROUP BY TT.productsubcategoryid
# LIMIT 100;
# Out:
#  * postgresql://ec3_user:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/adventuretime
# 10 rows affected.
# [(1, -0.0447157836330059),
#  (31, 0.743104524356119),
#  (2, -0.0712052511600406),
#  (21, 0.125234738293598),
#  (14, -0.175283667451036),
#  (12, -0.123039951165905),
#  (3, 0.0466409832972005),
#  (28, 0.414354528658018),
#  (37, -0.325206132024367),
#  (20, 0.215995614365503)]

# %% [markdown]
# ---------

# %% [markdown]
# We have a negative correlation when these products have lower prices, people buy them more, or when they go up in price they buy less.
#
#
# We have a positive correlation which is a rare case when as prices goes up or down, your sales also goes up or down just like the price.

# %% [markdown]
# ## Finding our top salespeople
#
# As mentioned earlier, we want to find our best salespeople and see whether or not we can incentivize them in an appropriate manner. Namely, we want to determine if the commission percentage we give them motivates them to make more and bigger sales.

# %% [markdown]
# ### Exercise 5:
#
# Find the top five performing salespeople by using the `salesytd` (Sales, year-to-date) column. (We only need to know the `businessentityid` for each salesperson as this uniquely identifies each.) Why might you be skeptical of these numbers right now?

# %% [markdown]
# **Answer.**

# %%
# %%sql
#
# SELECT businessentityid, salesytd
# FROM salesperson
# ORDER BY salesytd DESC
# LIMIT 5;
# Out:
#  * postgresql://ec3_user:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/adventuretime
# 5 rows affected.
# [(276, 4251368.5497),
#  (289, 4116871.2277),
#  (275, 3763178.1787),
#  (277, 3189418.3662),
#  (290, 3121616.3202)]

# %% [markdown]
# From the column salesytd we obtain the information of the total sales made for several years from a sales person, this can cause the simpson paradox, so it would be necessary to analyze in more detail the sales by year and by each seller to make a better analysis to avoid falling into the simpsom paradox

# %% [markdown]
# ---------

# %% [markdown]
# ### Exercise 6:
#
# Using ```salesorderheader```, find the top 5 salespeople who made the most sales **in the most recent year** (2014). (There is a column called `subtotal` - use that.) Sales that do not have an associated salesperson should be excluded from your calculations and final output. All orders that were made within the 2014 calendar year should be included.
#
# **Hint:** You can use the syntax `'1970-01-01'::date` to generate an arbitrary date in PostgreSQL and compare this to specific dates in the tables.

# %% [markdown]
# **Answer.**

# %%
# %%sql
# SELECT salespersonid, SUM(subtotal) AS totalsales2014
# FROM salesorderheader
# WHERE salespersonid IS NOT NULL AND orderdate>='2014-01-01'
# GROUP BY salespersonid
# ORDER BY totalsales2014 DESC
# LIMIT 5;
# Out:
#  * postgresql://ec3_user:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/adventuretime
# 5 rows affected.
# [(Decimal('289'), 1382996.5839),
#  (Decimal('276'), 1271088.5216),
#  (Decimal('275'), 1057247.3786),
#  (Decimal('282'), 1044810.8277),
#  (Decimal('277'), 1040093.4071)]

# %% [markdown]
# ---------

# %% [markdown]
# ### Exercise 7:
#
# Looking at the documentation, you will see that `subtotal` in the ```salesorderheader``` table is calculated from other tables in the database. To validate this figure (instead of trusting it blindly), let's calculate `subtotal` manually. Using the ```salesorderdetail``` and ```salesorderheader``` tables, calculate the sales for each salesperson for **this past year** (2014) and display results for the top 5 salespeople.
#
# **Hint:** You will have to ```JOIN``` ```salesorderdetail``` on ```salesorderheader``` to get the salesperson, calculate line totals for each sale using appropriate discounts, then sum all the line totals to get the total sale. You will want to use ```WITH``` clauses again to keep things sane.

# %% [markdown]
# **Answer.**

# %%
# %%sql
#
# WITH manualsubtotal AS(
#     SELECT salespersonid,P.salesorderid,SUM((orderqty*unitprice)*(1-unitpricediscount)) AS sub
#     FROM salesorderdetail P
#          JOIN salesorderheader N ON P.salesorderid = N.salesorderid
#          WHERE salespersonid IS NOT NULL AND orderdate>='2014-01-01'
#     GROUP BY salespersonid, P.salesorderid
#     )
# SELECT salespersonid, SUM(sub) AS totalsales2014
# FROM manualsubtotal
# GROUP BY salespersonid
# ORDER BY totalsales2014 DESC
# LIMIT 5;
# Out:
#  * postgresql://ec3_user:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/adventuretime
# 5 rows affected.
# [(Decimal('289'), 1382996.58391),
#  (Decimal('276'), 1271088.521461),
#  (Decimal('275'), 1057247.378572),
#  (Decimal('282'), 1044810.827687),
#  (Decimal('277'), 1040093.406901)]

# %% [markdown]
# ---------

# %% [markdown]
# ### Exercise 8:
#
# Using ```corr()```, see if there is a positive relationship between total sales and commission percentage.

# %% [markdown]
# **Answer.**

# %%
# %%sql
#
# WITH manualsubtotal AS(
#     SELECT salespersonid,P.salesorderid,SUM((orderqty*unitprice)*(1-unitpricediscount)) AS sub
#     FROM salesorderdetail P
#          JOIN salesorderheader N ON P.salesorderid = N.salesorderid
#          WHERE salespersonid IS NOT NULL AND orderdate>='2014-01-01'
#     GROUP BY P.salesorderid,salespersonid
#     ), totalsls2014 AS(
#     SELECT salespersonid, SUM(sub) AS totalsales2014
#     FROM manualsubtotal
#     GROUP BY salespersonid)
#
# SELECT corr(totalsales2014,commissionpct) AS CORR
# FROM totalsls2014 T
# JOIN salesperson S ON T.salespersonid = S.businessentityid;
# Out:
#  * postgresql://ec3_user:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/adventuretime
# 1 rows affected.
# [(0.737527789211786,)]

# %% [markdown]
# ---------

# %% [markdown]
# ### Exercise 9:
#
# Remember how we mentioned that products were sold in many regions? This is why you had to work with the `culture` value before to get the English language descriptions. To make matters worse, you are told the sales are recorded in **local** currency, so your previous analysis is flawed, and you must convert all amounts to USD if you wish to compare the different salespeople fairly!
#
# Use the `countryregioncurrency` table in combination with the `salesperson` and `salesterritory` ones to figure out the relevant currency symbol for each of the top salespeople.

# %% [markdown]
# **Answer.**

# %%
# %%sql
#
# WITH manualsubtotal AS(
#     SELECT salespersonid,P.salesorderid,SUM((orderqty*unitprice)*(1-unitpricediscount)) AS sub
#     FROM salesorderdetail P
#          JOIN salesorderheader N ON P.salesorderid = N.salesorderid
#          WHERE salespersonid IS NOT NULL AND orderdate>='2014-01-01'
#     GROUP BY salespersonid, P.salesorderid
#     ), totalsls2014 AS(
#         SELECT salespersonid, SUM(sub) AS totalsales2014
#         FROM manualsubtotal
#         GROUP BY salespersonid
#         ORDER BY totalsales2014 DESC
#         LIMIT 5)
#
# SELECT salespersonid, commissionpct, S.territoryid, ST.countryregioncode, currencycode
# FROM totalsls2014 T
# JOIN salesperson S ON T.salespersonid = S.businessentityid
# JOIN salesterritory ST ON S.territoryid= ST.territoryid
# JOIN countryregioncurrency CRC ON ST.countryregioncode=CRC.countryregioncode;
# Out:
#  * postgresql://ec3_user:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/adventuretime
# 5 rows affected.
# [(Decimal('282'), 0.015, 6, 'CA', 'CAD'),
#  (Decimal('289'), 0.02, 10, 'GB', 'GBP'),
#  (Decimal('276'), 0.015, 4, 'US', 'USD'),
#  (Decimal('277'), 0.015, 3, 'US', 'USD'),
#  (Decimal('275'), 0.012, 2, 'US', 'USD')]

# %% [markdown]
# ---------

# %% [markdown]
# ### Exercise 10:
#
# Now that we have the currency codes associated with each salesperson, redo Exercise 7 to take the currency exchange into account. If there are salespeople in the top 5 that weren't there before, explain why.
#
# **Hint:** The rates in the```currencyrate``` table always go from `FromCurrencyCode=USD` to `ToCurrencyCode=<Desired Currency Code>`, and they are listed every day. When calculating line totals, use the `AverageRate` for that day. You should be able to reuse a lot of Exercise 7.

# %% [markdown]
# **Answer.**

# %%
# %%sql
#
# WITH ProvTable AS(
#     SELECT salespersonid,P.salesorderid, orderdate, orderqty, unitprice, unitpricediscount, currencycode
#     FROM salesorderdetail P
#          JOIN salesorderheader N ON P.salesorderid = N.salesorderid
#          JOIN salesterritory ST ON N.territoryid= ST.territoryid
#          JOIN countryregioncurrency CRC ON ST.countryregioncode=CRC.countryregioncode
#          WHERE salespersonid IS NOT NULL AND orderdate>='2014-01-01'
#     ), manualsubtotal AS(
#         SELECT salespersonid, salesorderid,SUM(((orderqty*unitprice)*(1-unitpricediscount))/averagerate) AS sub
#         FROM ProvTable PT
#              JOIN currencyrate CR ON (PT.orderdate=CR.currencyratedate AND PT.currencycode=CR.tocurrencycode)
#         GROUP BY salesorderid,salespersonid
#     )
# SELECT salespersonid, SUM(sub) AS totalsales2014
# FROM manualsubtotal
# GROUP BY salespersonid
# ORDER BY totalsales2014 DESC
# LIMIT 5;
# Out:
#  * postgresql://ec3_user:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/adventuretime
# 5 rows affected.
# [(Decimal('282'), 1625063.86527028),
#  (Decimal('276'), 1271088.521461),
#  (Decimal('275'), 1057247.378572),
#  (Decimal('277'), 1040093.406901),
#  (Decimal('289'), 883042.500218658)]

# %% [markdown]
# ### Exercise 11:
#
# How does the correlation from Exercise 8 change once you've adjusted for the currency?

# %% [markdown]
# **Answer.**

# %% [markdown]
# ---------

# %%
# %%sql
# WITH ProvTable AS(
#     SELECT salespersonid,P.salesorderid, orderdate, orderqty, unitprice, unitpricediscount, currencycode
#     FROM salesorderdetail P
#          JOIN salesorderheader N ON P.salesorderid = N.salesorderid
#          JOIN salesterritory ST ON N.territoryid= ST.territoryid
#          JOIN countryregioncurrency CRC ON ST.countryregioncode=CRC.countryregioncode
#          WHERE salespersonid IS NOT NULL AND orderdate>='2014-01-01'
#     ), manualsubtotal AS(
#         SELECT salespersonid, salesorderid,SUM(((orderqty*unitprice)*(1-unitpricediscount))/averagerate) AS sub
#         FROM ProvTable PT
#              JOIN currencyrate CR ON (PT.orderdate=CR.currencyratedate AND PT.currencycode=CR.tocurrencycode)
#         GROUP BY salesorderid,salespersonid
#     ), totalsls2014 AS(
#     SELECT salespersonid, SUM(sub) AS totalsales2014
#     FROM manualsubtotal
#     GROUP BY salespersonid)
#
# SELECT corr(totalsales2014,commissionpct) AS CORR
# FROM totalsls2014 T
# JOIN salesperson S ON T.salespersonid = S.businessentityid;
# Out:
#  * postgresql://ec3_user:***@extendedcase-3-db.cxqxxdrtqk3d.us-east-2.rds.amazonaws.com/adventuretime
# 1 rows affected.
# [(0.590487356650375,)]

# %% [markdown]
# This correlation decreases with the real value of sales in USD
