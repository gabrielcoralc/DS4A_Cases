# %% [markdown]
# # How should I price auto insurance in the United States?

# %% [markdown]
# ## Introduction

# %% [markdown]
# **Business Context.** The ability to price an insurance quote properly has a significant impact on insurers' management decisions and financial statements. You are the chief data scientist at a new startup insurance company focusing on providing affordable insurance to millennials. You are tasked to assess the current state of insurance companies to see what factors large insurance providers charge premiums for. Fortunately for you, your company has compiled a dataset by surveying what people currently pay for insurance from large companies. Your findings will be used as the basis of developing your company's millenial car insurance offering.
#
# **Business Problem.** Your task is to build a **minimal** model to predict the cost of insurance from the data set using various characteristics of a policyholder.
#
# **Analytical Context.** The data resides in a CSV file which has been pre-cleaned for you and can directly be read in. Throughout the case, you will be iterating on your initial model many times based on common pitfalls that arise which we discussed in previous cases. You will be using the Python `statsmodels` package to create and analyze these linear models.

# %%
### Load relevant packages

import pandas                  as pd
import numpy                   as np
import matplotlib.pyplot       as plt
import seaborn                 as sns
import statsmodels.api         as sm
import statsmodels.formula.api as smf
import os

# This statement allow to display plot without asking to 
# %matplotlib inline

# always make it pretty 
plt.style.use('ggplot')

# %% [markdown]
# ## Diving into the data

# %%
df = pd.read_csv('Allstate-cost-cleaned.csv',
    dtype = { # indicate categorical variables
        'A': 'category',
        'B': 'category',
        'C': 'category',
        'D': 'category',
        'E': 'category',
        'F': 'category',
        'G': 'category',
        'car_value': 'category',
        'state': 'category'
    }
)

# %% [markdown]
# The following are the columns in the dataset:
#
# 1. **state**: State where shopping point occurred
# 2. **group_size**: How many people will be covered under the policy (1, 2, 3 or 4)
# 3. **homeowner**: Whether the customer owns a home (0=no, 1=yes)
# 4. **car_age**: Age of the customer's car (How old the car is)
# 5. **car_value**: Value of the car when it was new
# 6. **risk_factor**: An ordinal assessment of how risky the customer is (0,1, 2, 3, 4)
# 7. **age_oldest**: Age of the oldest person in customer's group
# 8. **age_youngest**: Age of the youngest person in customer's group
# 9. **married_couple**: Does the customer group contain a married couple (0=no, 1=yes)
# 10. **C_previous**: What the customer formerly had or currently has for product option C (0=nothing, 1, 2, 3,4)
# 11. **duration_previous**: How long (in years) the customer was covered by their previous issuer
# 12. **A,B,C,D,E,F,G**: The coverage options:
# 13. **A**: Collision (levels: 0, 1, 2);
# 14. **B**: Towing (levels: 0, 1);
# 15. **C**: Bodily Injury (BI, levels: 1, 2, 3, 4);
# 16. **D**: Property Damage (PD, levels 1, 2, 3);
# 17. **E**: Rental Reimbursement (RR, levels: 0, 1);
# 18. **F**: Comprehensive (Comp, levels: 0, 1, 2, 3);
# 19. **G**: Medical/Personal Injury Protection (Med/PIP, levels: 1, 2, 3, 4)
# 20. **cost**: cost of the quoted coverage options

# %%
df.head(10)
# Out:
#    Unnamed: 0 state  group_size  homeowner  car_age car_value  risk_factor  \
# 0           0    OK           1          0        9         f          0.0
# 1           1    OK           1          0        9         f          0.0
# 2           2    PA           1          1        7         f          0.0
# 3           3    PA           1          1        7         f          0.0
# 4           4    AR           1          0        4         d          4.0
# 5           5    AR           1          0        4         d          4.0
# 6           6    AR           1          0        4         d          4.0
# 7           7    OK           1          0       13         f          3.0
# 8           8    OK           1          0       13         f          3.0
# 9           9    OK           1          0       13         f          3.0
#
#    age_oldest  age_youngest  married_couple  C_previous  duration_previous  A  \
# 0          24            24               0         3.0                9.0  0
# 1          24            24               0         3.0                9.0  2
# 2          74            74               0         2.0               15.0  2
# 3          74            74               0         2.0               15.0  2
# 4          26            26               0         3.0                1.0  1
# 5          26            26               0         3.0                1.0  1
# 6          26            26               0         3.0                1.0  1
# 7          22            22               0         0.0                0.0  0
# 8          22            22               0         0.0                0.0  2
# 9          22            22               0         0.0                0.0  2
#
#    B  C  D  E  F  G  cost
# 0  0  1  1  0  0  4   543
# 1  1  1  3  1  3  2   611
# 2  0  2  3  1  2  2   691
# 3  0  2  3  1  2  2   695
# 4  0  1  1  0  2  2   628
# 5  0  2  1  0  2  2   625
# 6  0  2  1  0  2  2   628
# 7  0  1  1  0  0  2   596
# 8  0  1  1  0  3  2   711
# 9  0  1  1  0  3  2   722

# %% [markdown]
# ### Exercise 1:
#
# Write code to visualize the relationship between cost and the following variables. Choose your plots judiciously based on what you know about each variable. Different variable types (categorical vs. numerical) should have different types of plots (e.g. scatter, boxplot, violin plot, etc.) Group your plots together using the `plt.subplot()` function.
#
# 1. `car_age`
# 2. `age_oldest`
# 3. `age_youngest`
# 4. `duration_previous`
# 5. `C_previous`
# 6. `homeowner`
# 7. `group_size`
# 8. `car_age`
# 9. Categories A-G (7 different plots)

# %% [markdown]
# **Answer.**

# %%
varstolook = ["car_age", "age_oldest", "age_youngest", "duration_previous", "C_previous", "homeowner","group_size","A","B","C","D","E","F","G"]

plt.figure(figsize=(20,10))
for i,var in enumerate(varstolook):
    plt.subplot(5,3,i+1)
    if var in ["A","B","C","D","E","F","G","car_age"]:
        sns.violinplot(x=var, y='cost', data=df)
    else:
        if var in [ "age_oldest", "age_youngest", "duration_previous"]:
            sns.scatterplot(x=var,y='cost',data=df, alpha=0.10,color='b')
            plt.tight_layout(2)
            
        else:
            sns.boxplot(x=var, y='cost', data=df)

# %% [markdown]
# ----------

# %% [markdown]
# ### Exercise 2:
#
# Convert all categorical data to be in the one-hot encoding format.

# %% [markdown]
# **Answer.**

# %%
df_dummies=pd.get_dummies(df,columns=["state","car_value","A","B","C","D","E","F","G"],prefix_sep='_',drop_first=True)

# %% [markdown]
# ----------

# %% [markdown]
# ## Fitting a multiple linear regression

# %% [markdown]
# ### Exercise 3:
#
# Split your data into training and testing sets (an 80-20 split is a good starting point).
#
# **Note:** Keep random seed as 1337 in the code cell

# %% [markdown]
# **Answer.**

# %% [markdown]
# ----------

# %%
np.random.seed(1337) # a seed makes the analysis reproducible
                     # so everyone will get the same results
ndata = len(df)
# Randomly choose 0.8n indices between 1 and n
idx_train = np.random.choice(range(ndata),int(0.8*ndata),replace=False)
# The test set is comprised from all the indices that were
# not selected in the training set:
idx_test  = np.asarray(list(set(range(ndata)) - set(idx_train)))
train     = df.iloc[idx_train] # the training data set
test      = df.iloc[idx_test]  # the test data set
print(train.shape) 
print(test.shape)
# Out:
# (12386, 20)
# (3097, 20)

# %% [markdown]
# ### Exercise 4:
#
# #### 4.1
#
# Fit a multiple linear regression model to the training data regressing cost against all the other variables. Call this `model_all`. What is the AIC value?

# %% [markdown]
# **Answer.**

# %% [markdown]
# ----------

# %%
variables=df.columns[1:-2]
#Write down the regression formula
formula="cost ~ "
for varss in variables:
    formula+= varss + " + " 
formula+= df.columns[-2]
model = smf.ols(formula = formula, 
                 data = train).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   cost   R-squared:                       0.438
# Model:                            OLS   Adj. R-squared:                  0.435
# Method:                 Least Squares   F-statistic:                     143.0
# Date:                Sun, 05 Jul 2020   Prob (F-statistic):               0.00
# Time:                        19:08:25   Log-Likelihood:                -61546.
# No. Observations:               12344   AIC:                         1.232e+05
# Df Residuals:                   12276   BIC:                         1.237e+05
# Df Model:                          67
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept           683.8289      8.594     79.566      0.000     666.982     700.675
# state[T.AR]           0.4072      3.106      0.131      0.896      -5.682       6.496
# state[T.CO]         -10.9356      2.572     -4.252      0.000     -15.977      -5.894
# state[T.CT]          28.5326      2.868      9.948      0.000      22.911      34.155
# state[T.DC]          35.6920      4.593      7.772      0.000      26.690      44.694
# state[T.DE]          33.3884      4.455      7.495      0.000      24.656      42.120
# state[T.FL]          11.2874      2.162      5.222      0.000       7.050      15.525
# state[T.GA]           6.6917      2.381      2.811      0.005       2.025      11.358
# state[T.IA]         -50.9502      3.529    -14.439      0.000     -57.867     -44.034
# state[T.ID]         -21.3817      4.126     -5.183      0.000     -29.469     -13.295
# state[T.IN]         -11.6240      2.573     -4.518      0.000     -16.667      -6.581
# state[T.KS]          -9.2766      4.385     -2.116      0.034     -17.871      -0.682
# state[T.KY]          19.9873      2.925      6.833      0.000      14.254      25.721
# state[T.MD]          21.4571      2.467      8.697      0.000      16.621      26.293
# state[T.ME]         -36.2676      3.947     -9.189      0.000     -44.004     -28.531
# state[T.MO]         -22.9082      2.975     -7.701      0.000     -28.739     -17.077
# state[T.MS]          -0.9339      3.280     -0.285      0.776      -7.364       5.496
# state[T.MT]         -13.4074      6.163     -2.175      0.030     -25.488      -1.327
# state[T.ND]           3.1635      6.064      0.522      0.602      -8.724      15.051
# state[T.NE]         -14.4920      5.632     -2.573      0.010     -25.531      -3.453
# state[T.NH]         -21.4775      3.776     -5.688      0.000     -28.879     -14.076
# state[T.NM]          -1.7314      3.792     -0.457      0.648      -9.164       5.701
# state[T.NV]          21.1240      2.804      7.535      0.000      15.629      26.619
# state[T.NY]          38.0610      2.406     15.821      0.000      33.346      42.777
# state[T.OH]          -8.9122      2.309     -3.859      0.000     -13.439      -4.385
# state[T.OK]         -12.2284      2.738     -4.467      0.000     -17.595      -6.862
# state[T.OR]         -11.2545      2.843     -3.959      0.000     -16.827      -5.682
# state[T.PA]           9.7410      2.214      4.400      0.000       5.402      14.080
# state[T.RI]          25.2915      4.204      6.016      0.000      17.051      33.532
# state[T.SD]         -13.6322     12.711     -1.072      0.284     -38.548      11.284
# state[T.TN]         -12.0365      2.617     -4.599      0.000     -17.167      -6.906
# state[T.UT]         -17.0342      2.858     -5.961      0.000     -22.636     -11.433
# state[T.WA]           2.8072      2.589      1.084      0.278      -2.267       7.881
# state[T.WI]         -33.0978      3.001    -11.028      0.000     -38.981     -27.215
# state[T.WV]          30.0249      4.311      6.965      0.000      21.575      38.475
# state[T.WY]          -2.9505      7.495     -0.394      0.694     -17.643      11.742
# car_value[T.b]      -64.8351      9.957     -6.511      0.000     -84.353     -45.317
# car_value[T.c]      -50.2877      8.157     -6.165      0.000     -66.277     -34.298
# car_value[T.d]      -47.2327      8.069     -5.853      0.000     -63.050     -31.415
# car_value[T.e]      -46.5783      8.052     -5.785      0.000     -62.362     -30.795
# car_value[T.f]      -46.8200      8.064     -5.806      0.000     -62.626     -31.014
# car_value[T.g]      -42.4517      8.089     -5.248      0.000     -58.307     -26.597
# car_value[T.h]      -34.8746      8.195     -4.256      0.000     -50.938     -18.811
# car_value[T.i]      -12.6207      9.025     -1.398      0.162     -30.311       5.070
# A[T.1]               28.3534      1.522     18.631      0.000      25.370      31.336
# A[T.2]               33.0719      1.839     17.986      0.000      29.468      36.676
# B[T.1]                1.5023      0.789      1.904      0.057      -0.045       3.049
# C[T.2]                1.0212      1.122      0.911      0.363      -1.177       3.220
# C[T.3]                1.0917      1.158      0.943      0.346      -1.178       3.362
# C[T.4]                2.6260      1.737      1.511      0.131      -0.780       6.032
# D[T.2]               -0.6757      1.201     -0.563      0.574      -3.029       1.678
# D[T.3]               -0.8577      1.249     -0.687      0.492      -3.305       1.590
# E[T.1]                7.9884      0.868      9.201      0.000       6.287       9.690
# F[T.1]               16.8542      1.665     10.122      0.000      13.590      20.118
# F[T.2]               15.2948      1.603      9.543      0.000      12.153      18.436
# F[T.3]               11.2381      2.346      4.790      0.000       6.639      15.837
# G[T.2]                8.5608      0.944      9.070      0.000       6.711      10.411
# G[T.3]                0.9014      1.186      0.760      0.447      -1.423       3.226
# G[T.4]                4.3097      1.256      3.431      0.001       1.847       6.772
# group_size            3.0503      1.486      2.052      0.040       0.137       5.963
# homeowner           -14.7787      0.732    -20.179      0.000     -16.214     -13.343
# car_age              -0.7014      0.068    -10.312      0.000      -0.835      -0.568
# risk_factor          -0.3335      0.229     -1.456      0.145      -0.782       0.115
# age_oldest            0.6127      0.064      9.583      0.000       0.487       0.738
# age_youngest         -1.0064      0.063    -16.078      0.000      -1.129      -0.884
# married_couple       -9.6351      1.396     -6.900      0.000     -12.372      -6.898
# C_previous           -6.2903      0.360    -17.488      0.000      -6.995      -5.585
# duration_previous    -1.5291      0.073    -20.935      0.000      -1.672      -1.386
# ==============================================================================
# Omnibus:                      540.280   Durbin-Watson:                   1.991
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1270.951
# Skew:                           0.263   Prob(JB):                    1.04e-276
# Kurtosis:                       4.481   Cond. No.                     5.18e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.18e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# #### 4.2
#
# According to `model_all`, which states are most and least expensive?

# %% [markdown]
# **Answer.**

# %% [markdown]
# ----------

# %%
states=list(df["state"].unique())
sorted(states)[0]
# Out:
# 'AL'

# %%
coeffs=model.params.reset_index()
least_exp=coeffs[coeffs["index"].apply(lambda x: "state" in x)].sort_values(0).head(5)
least_exp
# Out:
#           index          0
# 8   state[T.IA] -50.950227
# 14  state[T.ME] -36.267581
# 33  state[T.WI] -33.097816
# 15  state[T.MO] -22.908192
# 20  state[T.NH] -21.477534

# %%
most_exp=coeffs[coeffs["index"].apply(lambda x: "state" in x)].sort_values(0).tail(5)
most_exp
# Out:
#           index          0
# 3   state[T.CT]  28.532641
# 34  state[T.WV]  30.024861
# 5   state[T.DE]  33.388410
# 4   state[T.DC]  35.692022
# 23  state[T.NY]  38.061025

# %% [markdown]
# #### 4.3
#
# Interpret the coefficients of `group_size`, `homeowner`, `car_age`, `risk_factor`, `age_oldest`, `age_youngest`       `married_couple` , `duration_previous`. Do the signs and values of these coefficients make sense to you in the context of this business problem?

# %% [markdown]
# **Answer.**

# %% [markdown]
# ----------

# %% [markdown]
# ### Exercise 5:
#
# Which variables from `model_all` are statistically significant? (For categorical variables, consider them to be significant if at least one of their categories are statistically significant). Refit the model using only these variables; call this `model_sig`. How does this model compare to the previous model?

# %% [markdown]
# **Answer.**

# %%
variables=df.columns[1:6]
variables=variables.append(df.columns[7:13])
variables=variables.append(df.columns[16:18])
#Write down the regression formula
formula="cost ~ "
for varss in variables:
    formula+= varss + " + " 
formula+= df.columns[-2]
model_sig = smf.ols(formula = formula, 
                 data = train).fit()
model_sig.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   cost   R-squared:                       0.438
# Model:                            OLS   Adj. R-squared:                  0.435
# Method:                 Least Squares   F-statistic:                     159.5
# Date:                Mon, 06 Jul 2020   Prob (F-statistic):               0.00
# Time:                        21:11:15   Log-Likelihood:                -61550.
# No. Observations:               12344   AIC:                         1.232e+05
# Df Residuals:                   12283   BIC:                         1.237e+05
# Df Model:                          60
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept           683.7532      8.569     79.793      0.000     666.956     700.550
# state[T.AR]           0.2411      3.088      0.078      0.938      -5.812       6.295
# state[T.CO]         -11.2359      2.551     -4.405      0.000     -16.236      -6.236
# state[T.CT]          27.6623      2.823      9.801      0.000      22.130      33.195
# state[T.DC]          35.5594      4.586      7.754      0.000      26.570      44.549
# state[T.DE]          32.1718      4.419      7.281      0.000      23.510      40.833
# state[T.FL]          10.3231      2.126      4.856      0.000       6.157      14.490
# state[T.GA]           6.5567      2.347      2.794      0.005       1.957      11.157
# state[T.IA]         -51.2824      3.499    -14.658      0.000     -58.140     -44.425
# state[T.ID]         -21.6288      4.106     -5.267      0.000     -29.678     -13.580
# state[T.IN]         -12.4824      2.512     -4.969      0.000     -17.407      -7.558
# state[T.KS]          -9.8189      4.369     -2.247      0.025     -18.383      -1.255
# state[T.KY]          19.3006      2.907      6.640      0.000      13.603      24.998
# state[T.MD]          20.6077      2.427      8.492      0.000      15.851      25.365
# state[T.ME]         -37.1284      3.906     -9.506      0.000     -44.784     -29.472
# state[T.MO]         -23.3079      2.960     -7.874      0.000     -29.110     -17.506
# state[T.MS]          -1.2728      3.264     -0.390      0.697      -7.671       5.125
# state[T.MT]         -13.6329      6.153     -2.216      0.027     -25.693      -1.573
# state[T.ND]           2.6334      6.018      0.438      0.662      -9.164      14.431
# state[T.NE]         -15.1524      5.620     -2.696      0.007     -26.168      -4.137
# state[T.NH]         -22.3175      3.744     -5.962      0.000     -29.655     -14.980
# state[T.NM]          -2.2353      3.772     -0.593      0.553      -9.629       5.158
# state[T.NV]          20.5030      2.785      7.362      0.000      15.044      25.962
# state[T.NY]          37.4942      2.365     15.851      0.000      32.858      42.131
# state[T.OH]          -9.4245      2.284     -4.127      0.000     -13.901      -4.948
# state[T.OK]         -12.9513      2.718     -4.764      0.000     -18.280      -7.623
# state[T.OR]         -11.6214      2.833     -4.102      0.000     -17.174      -6.069
# state[T.PA]           8.9963      2.186      4.115      0.000       4.711      13.281
# state[T.RI]          24.5672      4.189      5.865      0.000      16.357      32.778
# state[T.SD]         -13.7262     12.702     -1.081      0.280     -38.625      11.173
# state[T.TN]         -12.2444      2.613     -4.686      0.000     -17.366      -7.123
# state[T.UT]         -17.3061      2.851     -6.070      0.000     -22.894     -11.718
# state[T.WA]           2.3803      2.578      0.923      0.356      -2.672       7.433
# state[T.WI]         -33.4841      2.972    -11.265      0.000     -39.310     -27.658
# state[T.WV]          29.9070      4.301      6.954      0.000      21.477      38.337
# state[T.WY]          -3.0225      7.488     -0.404      0.686     -17.700      11.655
# car_value[T.b]      -64.9225      9.955     -6.521      0.000     -84.437     -45.408
# car_value[T.c]      -50.4199      8.155     -6.183      0.000     -66.405     -34.435
# car_value[T.d]      -47.4313      8.069     -5.879      0.000     -63.247     -31.616
# car_value[T.e]      -46.7688      8.051     -5.809      0.000     -62.551     -30.987
# car_value[T.f]      -46.9705      8.063     -5.826      0.000     -62.775     -31.166
# car_value[T.g]      -42.5867      8.087     -5.266      0.000     -58.439     -26.734
# car_value[T.h]      -34.9650      8.194     -4.267      0.000     -51.026     -18.904
# car_value[T.i]      -12.7092      9.017     -1.409      0.159     -30.384       4.965
# A[T.1]               28.3882      1.514     18.746      0.000      25.420      31.357
# A[T.2]               33.0172      1.835     17.994      0.000      29.421      36.614
# E[T.1]                8.7826      0.764     11.496      0.000       7.285      10.280
# F[T.1]               17.0954      1.654     10.337      0.000      13.854      20.337
# F[T.2]               15.4366      1.594      9.685      0.000      12.312      18.561
# F[T.3]               11.4273      2.341      4.882      0.000       6.839      16.016
# G[T.2]                8.5948      0.943      9.116      0.000       6.747      10.443
# G[T.3]                0.9764      1.183      0.826      0.409      -1.342       3.295
# G[T.4]                4.4238      1.250      3.538      0.000       1.973       6.875
# group_size            3.1892      1.483      2.150      0.032       0.282       6.097
# homeowner           -14.8278      0.729    -20.348      0.000     -16.256     -13.399
# car_age              -0.6936      0.068    -10.232      0.000      -0.827      -0.561
# age_oldest            0.6112      0.064      9.562      0.000       0.486       0.736
# age_youngest         -1.0026      0.063    -16.032      0.000      -1.125      -0.880
# married_couple       -9.6344      1.394     -6.910      0.000     -12.367      -6.901
# C_previous           -6.1292      0.307    -19.943      0.000      -6.732      -5.527
# duration_previous    -1.5392      0.073    -21.182      0.000      -1.682      -1.397
# ==============================================================================
# Omnibus:                      531.647   Durbin-Watson:                   1.992
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1233.937
# Skew:                           0.262   Prob(JB):                    1.13e-268
# Kurtosis:                       4.457   Cond. No.                     5.18e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.18e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
formula
# Out:
# 'cost ~ state + group_size + homeowner + car_age + car_value + age_oldest + age_youngest + married_couple + C_previous + duration_previous + A + E + F + G'

# %% [markdown]
# ----------

# %% [markdown]
# ### Exercise 6:
#
# In addition to the variables in `model_sig`, add terms for:
#
# 1. square of `age_youngest`
# 2. square term for the age of the car
# 3. interaction term for `car_value` and `age_youngest`
#
# and save it to a new model `model_sig_plus`.

# %% [markdown]
# **Answer.**

# %%
formula='cost ~ state + group_size + homeowner + car_age  + car_value*(age_youngest) + age_oldest + age_youngest + married_couple + C_previous + duration_previous + A + E + F + G+ I(age_youngest**2) + I(car_age**2)'
model_sig_plus = smf.ols(formula = formula, 
                 data = train).fit()
model_sig_plus.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   cost   R-squared:                       0.453
# Model:                            OLS   Adj. R-squared:                  0.450
# Method:                 Least Squares   F-statistic:                     145.1
# Date:                Mon, 06 Jul 2020   Prob (F-statistic):               0.00
# Time:                        22:22:23   Log-Likelihood:                -61385.
# No. Observations:               12344   AIC:                         1.229e+05
# Df Residuals:                   12273   BIC:                         1.234e+05
# Df Model:                          70
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                     703.9073     22.266     31.614      0.000     660.263     747.551
# state[T.AR]                     0.3712      3.058      0.121      0.903      -5.624       6.366
# state[T.CO]                    -9.8740      2.526     -3.909      0.000     -14.825      -4.923
# state[T.CT]                    29.4814      2.797     10.542      0.000      24.000      34.963
# state[T.DC]                    38.3384      4.540      8.445      0.000      29.440      47.237
# state[T.DE]                    31.7822      4.388      7.242      0.000      23.180      40.384
# state[T.FL]                     9.3865      2.107      4.454      0.000       5.256      13.517
# state[T.GA]                     7.1371      2.325      3.069      0.002       2.579      11.695
# state[T.IA]                   -50.2192      3.460    -14.515      0.000     -57.001     -43.437
# state[T.ID]                   -21.5599      4.060     -5.310      0.000     -29.518     -13.602
# state[T.IN]                   -12.2742      2.489     -4.932      0.000     -17.153      -7.396
# state[T.KS]                   -10.1074      4.318     -2.341      0.019     -18.570      -1.644
# state[T.KY]                    20.4693      2.878      7.112      0.000      14.828      26.111
# state[T.MD]                    21.8429      2.407      9.074      0.000      17.125      26.561
# state[T.ME]                   -35.4476      3.868     -9.165      0.000     -43.029     -27.866
# state[T.MO]                   -24.1602      2.930     -8.246      0.000     -29.903     -18.417
# state[T.MS]                    -0.7863      3.235     -0.243      0.808      -7.127       5.554
# state[T.MT]                   -15.2115      6.078     -2.503      0.012     -27.125      -3.298
# state[T.ND]                     2.5995      5.960      0.436      0.663      -9.084      14.283
# state[T.NE]                   -15.9394      5.553     -2.870      0.004     -26.824      -5.055
# state[T.NH]                   -22.3565      3.711     -6.025      0.000     -29.630     -15.083
# state[T.NM]                    -3.2193      3.743     -0.860      0.390     -10.556       4.117
# state[T.NV]                    21.4818      2.758      7.789      0.000      16.076      26.887
# state[T.NY]                    38.7097      2.346     16.501      0.000      34.111      43.308
# state[T.OH]                    -9.4818      2.260     -4.195      0.000     -13.913      -5.051
# state[T.OK]                   -13.9038      2.693     -5.163      0.000     -19.183      -8.625
# state[T.OR]                   -11.5514      2.802     -4.122      0.000     -17.045      -6.058
# state[T.PA]                     9.7667      2.167      4.506      0.000       5.518      14.015
# state[T.RI]                    22.7337      4.143      5.487      0.000      14.612      30.855
# state[T.SD]                    -7.2645     12.546     -0.579      0.563     -31.857      17.328
# state[T.TN]                   -11.9965      2.588     -4.636      0.000     -17.069      -6.924
# state[T.UT]                   -18.4968      2.825     -6.546      0.000     -24.035     -12.958
# state[T.WA]                     2.6961      2.561      1.053      0.292      -2.323       7.715
# state[T.WI]                   -31.5269      2.941    -10.719      0.000     -37.292     -25.762
# state[T.WV]                    32.0154      4.253      7.528      0.000      23.680      40.351
# state[T.WY]                    -2.5251      7.399     -0.341      0.733     -17.029      11.978
# car_value[T.b]                -71.4619     27.496     -2.599      0.009    -125.358     -17.566
# car_value[T.c]                -23.1179     22.263     -1.038      0.299     -66.756      20.520
# car_value[T.d]                -31.9985     22.124     -1.446      0.148     -75.365      11.368
# car_value[T.e]                -25.9447     22.079     -1.175      0.240     -69.223      17.334
# car_value[T.f]                -24.0454     22.100     -1.088      0.277     -67.366      19.275
# car_value[T.g]                -15.4862     22.192     -0.698      0.485     -58.986      28.014
# car_value[T.h]                 -2.6499     22.639     -0.117      0.907     -47.025      41.726
# car_value[T.i]                 46.3170     27.312      1.696      0.090      -7.219      99.852
# A[T.1]                         28.3897      1.496     18.975      0.000      25.457      31.322
# A[T.2]                         32.7613      1.813     18.071      0.000      29.208      36.315
# E[T.1]                          9.3410      0.756     12.362      0.000       7.860      10.822
# F[T.1]                         16.9421      1.634     10.371      0.000      13.740      20.144
# F[T.2]                         15.7151      1.575      9.980      0.000      12.628      18.802
# F[T.3]                         12.2270      2.312      5.289      0.000       7.696      16.758
# G[T.2]                          8.3904      0.932      9.003      0.000       6.564      10.217
# G[T.3]                          1.1902      1.170      1.018      0.309      -1.102       3.483
# G[T.4]                          4.6507      1.236      3.763      0.000       2.228       7.073
# group_size                      2.4283      1.469      1.653      0.098      -0.451       5.307
# homeowner                     -14.0860      0.722    -19.499      0.000     -15.502     -12.670
# car_age                        -1.3233      0.156     -8.487      0.000      -1.629      -1.018
# age_youngest                   -3.0073      0.396     -7.587      0.000      -3.784      -2.230
# car_value[T.b]:age_youngest     0.5691      0.528      1.077      0.281      -0.467       1.605
# car_value[T.c]:age_youngest    -0.0210      0.390     -0.054      0.957      -0.785       0.743
# car_value[T.d]:age_youngest     0.2966      0.379      0.782      0.434      -0.447       1.040
# car_value[T.e]:age_youngest     0.1792      0.378      0.475      0.635      -0.561       0.919
# car_value[T.f]:age_youngest     0.1452      0.378      0.384      0.701      -0.596       0.886
# car_value[T.g]:age_youngest     0.0613      0.380      0.161      0.872      -0.684       0.806
# car_value[T.h]:age_youngest    -0.0388      0.389     -0.100      0.921      -0.802       0.724
# car_value[T.i]:age_youngest    -0.5154      0.487     -1.058      0.290      -1.471       0.440
# age_oldest                      0.5087      0.064      8.010      0.000       0.384       0.633
# married_couple                 -8.5098      1.380     -6.167      0.000     -11.214      -5.805
# C_previous                     -6.7661      0.307    -22.040      0.000      -7.368      -6.164
# duration_previous              -1.5316      0.072    -21.321      0.000      -1.672      -1.391
# I(age_youngest ** 2)            0.0209      0.001     16.664      0.000       0.018       0.023
# I(car_age ** 2)                 0.0318      0.007      4.501      0.000       0.018       0.046
# ==============================================================================
# Omnibus:                      574.425   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1522.551
# Skew:                           0.239   Prob(JB):                         0.00
# Kurtosis:                       4.653   Cond. No.                     5.76e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.76e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
sns.lmplot(x='age_youngest', y='cost',hue="car_value",data=train, height=8, scatter_kws={"s": 10})

# %% [markdown]
# ----------

# %% [markdown]
# ## Feature selection

# %% [markdown]
# To reduce the number of features, it can often be helpful to aggregate the categories; for example, we can create a new variable by assigning each state to a larger region:

# %%
state_regions = pd.read_csv('https://raw.githubusercontent.com/cphalpert/census-regions/master/us%20census%20bureau%20regions%20and%20divisions.csv')
# should download the above file
state_regions
# Out:
#                    State State Code     Region            Division
# 0                 Alaska         AK       West             Pacific
# 1                Alabama         AL      South  East South Central
# 2               Arkansas         AR      South  West South Central
# 3                Arizona         AZ       West            Mountain
# 4             California         CA       West             Pacific
# 5               Colorado         CO       West            Mountain
# 6            Connecticut         CT  Northeast         New England
# 7   District of Columbia         DC      South      South Atlantic
# 8               Delaware         DE      South      South Atlantic
# 9                Florida         FL      South      South Atlantic
# 10               Georgia         GA      South      South Atlantic
# 11                Hawaii         HI       West             Pacific
# 12                  Iowa         IA    Midwest  West North Central
# 13                 Idaho         ID       West            Mountain
# 14              Illinois         IL    Midwest  East North Central
# 15               Indiana         IN    Midwest  East North Central
# 16                Kansas         KS    Midwest  West North Central
# 17              Kentucky         KY      South  East South Central
# 18             Louisiana         LA      South  West South Central
# 19         Massachusetts         MA  Northeast         New England
# 20              Maryland         MD      South      South Atlantic
# 21                 Maine         ME  Northeast         New England
# 22              Michigan         MI    Midwest  East North Central
# 23             Minnesota         MN    Midwest  West North Central
# 24              Missouri         MO    Midwest  West North Central
# 25           Mississippi         MS      South  East South Central
# 26               Montana         MT       West            Mountain
# 27        North Carolina         NC      South      South Atlantic
# 28          North Dakota         ND    Midwest  West North Central
# 29              Nebraska         NE    Midwest  West North Central
# 30         New Hampshire         NH  Northeast         New England
# 31            New Jersey         NJ  Northeast     Middle Atlantic
# 32            New Mexico         NM       West            Mountain
# 33                Nevada         NV       West            Mountain
# 34              New York         NY  Northeast     Middle Atlantic
# 35                  Ohio         OH    Midwest  East North Central
# 36              Oklahoma         OK      South  West South Central
# 37                Oregon         OR       West             Pacific
# 38          Pennsylvania         PA  Northeast     Middle Atlantic
# 39          Rhode Island         RI  Northeast         New England
# 40        South Carolina         SC      South      South Atlantic
# 41          South Dakota         SD    Midwest  West North Central
# 42             Tennessee         TN      South  East South Central
# 43                 Texas         TX      South  West South Central
# 44                  Utah         UT       West            Mountain
# 45              Virginia         VA      South      South Atlantic
# 46               Vermont         VT  Northeast         New England
# 47            Washington         WA       West             Pacific
# 48             Wisconsin         WI    Midwest  East North Central
# 49         West Virginia         WV      South      South Atlantic
# 50               Wyoming         WY       West            Mountain

# %% [markdown]
# ### Exercise 7:
#
# #### 7.1
#
# Create a new column where a state is replaced with the region it is in according to the above table.

# %% [markdown]
# **Answer.**

# %%
train2=train.merge(state_regions[["State Code","Region"]],left_on="state",right_on="State Code")

# %% [markdown]
# ----------

# %% [markdown]
# #### 7.2
#
# Fit the model as in `model_sig_plus` but this time use `region` instead of `state`. Call this `model_region`.

# %% [markdown]
# **Answer.**

# %%
formula='cost ~ Region + group_size + homeowner + car_age  + car_value + car_value*(age_youngest) + age_oldest + age_youngest + married_couple + C_previous + duration_previous + A + E + F + G+ I(age_youngest**2) + I(car_age**2)'
model_region = smf.ols(formula = formula, 
                 data = train2).fit()
model_region.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   cost   R-squared:                       0.380
# Model:                            OLS   Adj. R-squared:                  0.378
# Method:                 Least Squares   F-statistic:                     198.2
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):               0.00
# Time:                        19:32:12   Log-Likelihood:                -62159.
# No. Observations:               12344   AIC:                         1.244e+05
# Df Residuals:                   12305   BIC:                         1.247e+05
# Df Model:                          38
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                     703.7767     23.418     30.052      0.000     657.873     749.681
# Region[T.Northeast]            32.4951      1.227     26.486      0.000      30.090      34.900
# Region[T.South]                23.6082      1.014     23.291      0.000      21.621      25.595
# Region[T.West]                 13.4782      1.192     11.311      0.000      11.143      15.814
# car_value[T.b]                -85.7135     28.987     -2.957      0.003    -142.533     -28.894
# car_value[T.c]                -41.1899     23.544     -1.749      0.080     -87.340       4.961
# car_value[T.d]                -51.7700     23.391     -2.213      0.027     -97.621      -5.919
# car_value[T.e]                -43.4182     23.348     -1.860      0.063     -89.183       2.347
# car_value[T.f]                -41.4374     23.369     -1.773      0.076     -87.245       4.370
# car_value[T.g]                -33.3515     23.464     -1.421      0.155     -79.344      12.641
# car_value[T.h]                -16.8924     23.929     -0.706      0.480     -63.796      30.012
# car_value[T.i]                 29.0181     28.929      1.003      0.316     -27.687      85.723
# A[T.1]                         40.1784      1.376     29.203      0.000      37.482      42.875
# A[T.2]                         44.9859      1.731     25.994      0.000      41.594      48.378
# E[T.1]                         11.9659      0.791     15.132      0.000      10.416      13.516
# F[T.1]                         -3.9262      1.313     -2.989      0.003      -6.501      -1.352
# F[T.2]                         -3.4480      1.279     -2.697      0.007      -5.954      -0.942
# F[T.3]                         -7.5404      2.195     -3.436      0.001     -11.842      -3.239
# G[T.2]                         11.1127      0.930     11.948      0.000       9.290      12.936
# G[T.3]                          7.4616      1.052      7.091      0.000       5.399       9.524
# G[T.4]                          8.1477      1.255      6.494      0.000       5.689      10.607
# group_size                      0.4456      1.555      0.287      0.774      -2.602       3.493
# homeowner                     -14.7405      0.758    -19.452      0.000     -16.226     -13.255
# car_age                        -1.4270      0.164     -8.687      0.000      -1.749      -1.105
# age_youngest                   -3.0790      0.420     -7.337      0.000      -3.902      -2.256
# car_value[T.b]:age_youngest     0.7226      0.557      1.296      0.195      -0.370       1.815
# car_value[T.c]:age_youngest     0.2322      0.413      0.563      0.574      -0.576       1.041
# car_value[T.d]:age_youngest     0.5801      0.401      1.447      0.148      -0.206       1.366
# car_value[T.e]:age_youngest     0.4148      0.399      1.038      0.299      -0.368       1.198
# car_value[T.f]:age_youngest     0.3792      0.400      0.948      0.343      -0.405       1.163
# car_value[T.g]:age_youngest     0.2989      0.402      0.744      0.457      -0.489       1.087
# car_value[T.h]:age_youngest     0.1047      0.412      0.254      0.799      -0.702       0.912
# car_value[T.i]:age_youngest    -0.2687      0.517     -0.520      0.603      -1.281       0.744
# age_oldest                      0.5880      0.067      8.764      0.000       0.457       0.720
# married_couple                 -7.5076      1.461     -5.139      0.000     -10.371      -4.644
# C_previous                     -6.7451      0.320    -21.087      0.000      -7.372      -6.118
# duration_previous              -1.4763      0.076    -19.496      0.000      -1.625      -1.328
# I(age_youngest ** 2)            0.0185      0.001     14.011      0.000       0.016       0.021
# I(car_age ** 2)                 0.0369      0.007      4.960      0.000       0.022       0.051
# ==============================================================================
# Omnibus:                      422.573   Durbin-Watson:                   1.853
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              773.590
# Skew:                           0.275   Prob(JB):                    1.04e-168
# Kurtosis:                       4.096   Cond. No.                     5.72e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.72e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ----------

# %% [markdown]
# ### Exercise 8:
#
# #### 8.1
#
# What should we do next to minimize features?

# %% [markdown]
# **Answer.**

# %% [markdown]
# ----------

# %% [markdown]
# #### 8.2
#
# Using a method of your choice, find the numerical feature(s) in `model_region`, except for the three we added in Exercise 6, which exhibit multicollinearity. **Hint:** consider looking at correlations.

# %% [markdown]
# **Answer.**

# %%
M = model_region.model.data.exog # the design matrix X containing all
                               # predictors including dummy variables
                               # for categorical variables
param_names = model_region.model.data.param_names # parameter names
M_df = pd.DataFrame(M, columns=param_names) # as a pandas data frame
param_names
# Out:
# ['Intercept',
#  'Region[T.Northeast]',
#  'Region[T.South]',
#  'Region[T.West]',
#  'car_value[T.b]',
#  'car_value[T.c]',
#  'car_value[T.d]',
#  'car_value[T.e]',
#  'car_value[T.f]',
#  'car_value[T.g]',
#  'car_value[T.h]',
#  'car_value[T.i]',
#  'A[T.1]',
#  'A[T.2]',
#  'E[T.1]',
#  'F[T.1]',
#  'F[T.2]',
#  'F[T.3]',
#  'G[T.2]',
#  'G[T.3]',
#  'G[T.4]',
#  'group_size',
#  'homeowner',
#  'car_age',
#  'age_youngest',
#  'car_value[T.b]:age_youngest',
#  'car_value[T.c]:age_youngest',
#  'car_value[T.d]:age_youngest',
#  'car_value[T.e]:age_youngest',
#  'car_value[T.f]:age_youngest',
#  'car_value[T.g]:age_youngest',
#  'car_value[T.h]:age_youngest',
#  'car_value[T.i]:age_youngest',
#  'age_oldest',
#  'married_couple',
#  'C_previous',
#  'duration_previous',
#  'I(age_youngest ** 2)',
#  'I(car_age ** 2)']

# %%
# subset of predictors to plot:
M_sub = M_df[['group_size','homeowner','car_age','age_youngest','age_oldest','married_couple','C_previous','duration_previous','Region[T.Northeast]',
 'Region[T.South]',
 'Region[T.West]',
 'car_value[T.b]',
 'car_value[T.c]',
 'car_value[T.d]',
 'car_value[T.e]',
 'car_value[T.f]',
 'car_value[T.g]',
 'car_value[T.h]',
 'car_value[T.i]',
 'A[T.1]',
 'A[T.2]',
 'E[T.1]',
 'F[T.1]',
 'F[T.2]',
 'F[T.3]',
 'G[T.2]',
 'G[T.3]',
 'G[T.4]',]]
plt.figure(figsize=(15,15))
sns.heatmap(M_sub.corr(), cmap="RdYlBu", 
    annot=True, square=True,
    vmin=-0.8, vmax=0.8, fmt="+.1f")
plt.title("Correlations between predictors")
(M_sub.corr()>0.5)|(M_sub.corr()<-0.5)
# Out:
#                      group_size  homeowner  car_age  age_youngest  age_oldest  \
# group_size                 True      False    False         False       False
# homeowner                 False       True    False         False       False
# car_age                   False      False     True         False       False
# age_youngest              False      False    False          True        True
# age_oldest                False      False    False          True        True
# married_couple             True      False    False         False       False
# C_previous                False      False    False         False       False
# duration_previous         False      False    False         False       False
# Region[T.Northeast]       False      False    False         False       False
# Region[T.South]           False      False    False         False       False
# Region[T.West]            False      False    False         False       False
# car_value[T.b]            False      False    False         False       False
# car_value[T.c]            False      False    False         False       False
# car_value[T.d]            False      False    False         False       False
# car_value[T.e]            False      False    False         False       False
# car_value[T.f]            False      False    False         False       False
# car_value[T.g]            False      False    False         False       False
# car_value[T.h]            False      False    False         False       False
# car_value[T.i]            False      False    False         False       False
# A[T.1]                    False      False    False         False       False
# A[T.2]                    False      False    False         False       False
# E[T.1]                    False      False    False         False       False
# F[T.1]                    False      False    False         False       False
# F[T.2]                    False      False    False         False       False
# F[T.3]                    False      False    False         False       False
# G[T.2]                    False      False    False         False       False
# G[T.3]                    False      False    False         False       False
# G[T.4]                    False      False    False         False       False
#
#                      married_couple  C_previous  duration_previous  \
# group_size                     True       False              False
# homeowner                     False       False              False
# car_age                       False       False              False
# age_youngest                  False       False              False
# age_oldest                    False       False              False
# married_couple                 True       False              False
# C_previous                    False        True              False
# duration_previous             False       False               True
# Region[T.Northeast]           False       False              False
# Region[T.South]               False       False              False
# Region[T.West]                False       False              False
# car_value[T.b]                False       False              False
# car_value[T.c]                False       False              False
# car_value[T.d]                False       False              False
# car_value[T.e]                False       False              False
# car_value[T.f]                False       False              False
# car_value[T.g]                False       False              False
# car_value[T.h]                False       False              False
# car_value[T.i]                False       False              False
# A[T.1]                        False       False              False
# A[T.2]                        False       False              False
# E[T.1]                        False       False              False
# F[T.1]                        False       False              False
# F[T.2]                        False       False              False
# F[T.3]                        False       False              False
# G[T.2]                        False       False              False
# G[T.3]                        False       False              False
# G[T.4]                        False       False              False
#
#                      Region[T.Northeast]  Region[T.South]  ...  \
# group_size                         False            False  ...
# homeowner                          False            False  ...
# car_age                            False            False  ...
# age_youngest                       False            False  ...
# age_oldest                         False            False  ...
# married_couple                     False            False  ...
# C_previous                         False            False  ...
# duration_previous                  False            False  ...
# Region[T.Northeast]                 True             True  ...
# Region[T.South]                     True             True  ...
# Region[T.West]                     False            False  ...
# car_value[T.b]                     False            False  ...
# car_value[T.c]                     False            False  ...
# car_value[T.d]                     False            False  ...
# car_value[T.e]                     False            False  ...
# car_value[T.f]                     False            False  ...
# car_value[T.g]                     False            False  ...
# car_value[T.h]                     False            False  ...
# car_value[T.i]                     False            False  ...
# A[T.1]                             False            False  ...
# A[T.2]                             False            False  ...
# E[T.1]                             False            False  ...
# F[T.1]                             False            False  ...
# F[T.2]                             False            False  ...
# F[T.3]                             False            False  ...
# G[T.2]                             False            False  ...
# G[T.3]                             False            False  ...
# G[T.4]                             False            False  ...
#
#                      car_value[T.i]  A[T.1]  A[T.2]  E[T.1]  F[T.1]  F[T.2]  \
# group_size                    False   False   False   False   False   False
# homeowner                     False   False   False   False   False   False
# car_age                       False   False   False   False   False   False
# age_youngest                  False   False   False   False   False   False
# age_oldest                    False   False   False   False   False   False
# married_couple                False   False   False   False   False   False
# C_previous                    False   False   False   False   False   False
# duration_previous             False   False   False   False   False   False
# Region[T.Northeast]           False   False   False   False   False   False
# Region[T.South]               False   False   False   False   False   False
# Region[T.West]                False   False   False   False   False   False
# car_value[T.b]                False   False   False   False   False   False
# car_value[T.c]                False   False   False   False   False   False
# car_value[T.d]                False   False   False   False   False   False
# car_value[T.e]                False   False   False   False   False   False
# car_value[T.f]                False   False   False   False   False   False
# car_value[T.g]                False   False   False   False   False   False
# car_value[T.h]                False   False   False   False   False   False
# car_value[T.i]                 True   False   False   False   False   False
# A[T.1]                        False    True    True   False   False   False
# A[T.2]                        False    True    True   False   False   False
# E[T.1]                        False   False   False    True   False   False
# F[T.1]                        False   False   False   False    True   False
# F[T.2]                        False   False   False   False   False    True
# F[T.3]                        False   False    True   False   False   False
# G[T.2]                        False   False   False   False   False   False
# G[T.3]                        False   False   False   False   False   False
# G[T.4]                        False   False   False   False   False   False
#
#                      F[T.3]  G[T.2]  G[T.3]  G[T.4]
# group_size            False   False   False   False
# homeowner             False   False   False   False
# car_age               False   False   False   False
# age_youngest          False   False   False   False
# age_oldest            False   False   False   False
# married_couple        False   False   False   False
# C_previous            False   False   False   False
# duration_previous     False   False   False   False
# Region[T.Northeast]   False   False   False   False
# Region[T.South]       False   False   False   False
# Region[T.West]        False   False   False   False
# car_value[T.b]        False   False   False   False
# car_value[T.c]        False   False   False   False
# car_value[T.d]        False   False   False   False
# car_value[T.e]        False   False   False   False
# car_value[T.f]        False   False   False   False
# car_value[T.g]        False   False   False   False
# car_value[T.h]        False   False   False   False
# car_value[T.i]        False   False   False   False
# A[T.1]                False   False   False   False
# A[T.2]                 True   False   False   False
# E[T.1]                False   False   False   False
# F[T.1]                False   False   False   False
# F[T.2]                False   False   False   False
# F[T.3]                 True   False   False   False
# G[T.2]                False    True    True   False
# G[T.3]                False    True    True   False
# G[T.4]                False   False   False    True
#
# [28 rows x 28 columns]

# %% [markdown]
# We should take out "married_couple" and "age_youngest" from the model

# %% [markdown]
# ----------

# %% [markdown]
# #### 8.3:
#
# Refit `model_region` after dropping these redundant predictor(s); call this `model_region_no_oldest`.

# %% [markdown]
# **Answer.**

# %% [markdown]
# ----------

# %%
formula='cost ~ Region + group_size + homeowner + car_age  + car_value + car_value*(age_youngest) + age_youngest  + C_previous + duration_previous + A + E + F + G+ I(age_youngest**2) + I(car_age**2)'
model_region_no_oldest = smf.ols(formula = formula, 
                 data = train2).fit()
model_region_no_oldest.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   cost   R-squared:                       0.372
# Model:                            OLS   Adj. R-squared:                  0.370
# Method:                 Least Squares   F-statistic:                     202.2
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):               0.00
# Time:                        09:31:40   Log-Likelihood:                -62238.
# No. Observations:               12344   AIC:                         1.245e+05
# Df Residuals:                   12307   BIC:                         1.248e+05
# Df Model:                          36
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                     708.9042     23.531     30.126      0.000     662.779     755.029
# Region[T.Northeast]            32.3092      1.234     26.192      0.000      29.891      34.727
# Region[T.South]                23.5431      1.020     23.081      0.000      21.544      25.542
# Region[T.West]                 13.3317      1.199     11.120      0.000      10.982      15.682
# car_value[T.b]                -88.1557     29.171     -3.022      0.003    -145.335     -30.976
# car_value[T.c]                -39.2409     23.693     -1.656      0.098     -85.683       7.201
# car_value[T.d]                -49.3717     23.539     -2.097      0.036     -95.513      -3.231
# car_value[T.e]                -41.4748     23.496     -1.765      0.078     -87.530       4.581
# car_value[T.f]                -39.8899     23.518     -1.696      0.090     -85.988       6.208
# car_value[T.g]                -32.4083     23.613     -1.372      0.170     -78.694      13.877
# car_value[T.h]                -14.9934     24.080     -0.623      0.534     -62.195      32.208
# car_value[T.i]                 29.1384     29.108      1.001      0.317     -27.919      86.195
# A[T.1]                         40.4527      1.384     29.220      0.000      37.739      43.166
# A[T.2]                         45.2172      1.741     25.965      0.000      41.804      48.631
# E[T.1]                         12.1867      0.796     15.318      0.000      10.627      13.746
# F[T.1]                         -4.2982      1.321     -3.253      0.001      -6.888      -1.708
# F[T.2]                         -3.7207      1.286     -2.892      0.004      -6.242      -1.199
# F[T.3]                         -7.7303      2.208     -3.501      0.000     -12.059      -3.402
# G[T.2]                         11.2169      0.936     11.988      0.000       9.383      13.051
# G[T.3]                          7.3927      1.059      6.981      0.000       5.317       9.468
# G[T.4]                          7.9784      1.262      6.320      0.000       5.504      10.453
# group_size                      0.2890      0.772      0.375      0.708      -1.224       1.802
# homeowner                     -13.7948      0.756    -18.253      0.000     -15.276     -12.313
# car_age                        -1.3812      0.165     -8.358      0.000      -1.705      -1.057
# age_youngest                   -2.7410      0.419     -6.543      0.000      -3.562      -1.920
# car_value[T.b]:age_youngest     0.7488      0.561      1.335      0.182      -0.351       1.848
# car_value[T.c]:age_youngest     0.1966      0.415      0.473      0.636      -0.617       1.010
# car_value[T.d]:age_youngest     0.5286      0.404      1.310      0.190      -0.262       1.320
# car_value[T.e]:age_youngest     0.3719      0.402      0.925      0.355      -0.416       1.160
# car_value[T.f]:age_youngest     0.3342      0.403      0.830      0.406      -0.455       1.123
# car_value[T.g]:age_youngest     0.2598      0.405      0.642      0.521      -0.533       1.053
# car_value[T.h]:age_youngest     0.0411      0.414      0.099      0.921      -0.771       0.853
# car_value[T.i]:age_youngest    -0.3154      0.520     -0.607      0.544      -1.334       0.703
# C_previous                     -6.8336      0.322    -21.250      0.000      -7.464      -6.203
# duration_previous              -1.4121      0.076    -18.578      0.000      -1.561      -1.263
# I(age_youngest ** 2)            0.0208      0.001     15.796      0.000       0.018       0.023
# I(car_age ** 2)                 0.0356      0.007      4.758      0.000       0.021       0.050
# ==============================================================================
# Omnibus:                      420.030   Durbin-Watson:                   1.851
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              765.428
# Skew:                           0.275   Prob(JB):                    6.16e-167
# Kurtosis:                       4.089   Cond. No.                     5.72e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.72e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# #### 8.4
#
# What would you do to diagnose the `model_region_no_oldest` fit? What does this diagnosis suggest to you? (Hint: try plotting the residuals in various ways.)

# %% [markdown]
# **Answer.**

# %%
sm.qqplot(model_region_no_oldest.resid, line="s");

# %%
import scipy
plt.hist(model_region_no_oldest.resid, 
    density=True,     # the histogram integrates to 1 
                      # (so it can be compared to the normal distribution)
    bins=100,         #  draw a histogram with 100 bins of equal width
    label="residuals" # label for legend
    )
# now plot the normal distribution for comparison
xx = np.linspace(model_region_no_oldest.resid.min(), model_region_no_oldest.resid.max(), num=1000)
plt.plot(xx, scipy.stats.norm.pdf(xx, loc=0.0, scale=np.sqrt(model_region_no_oldest.scale)),
    label="normal distribution")
outliers = np.abs(model_region_no_oldest.resid)>4*np.sqrt(model_region_no_oldest.scale)
sns.rugplot(model_region_no_oldest.resid[outliers],
            color="C5", # otherwise the rugplot has the same color as the histogram
            label="outliers")
plt.legend(loc="upper right");

# %%
data_clean=train2.copy()

data_clean['Residuals']=model_region_no_oldest.resid

fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(16,8))

sns.violinplot(x='homeowner', y='Residuals',data=data_clean,
               
               widths=700,
               showextrema=True, ax=ax[0],alpha=0.02
               )
sns.scatterplot(x='homeowner',y='Residuals',data=data_clean,ax=ax[1])

# %%
data_clean=train2.copy()

data_clean['Residuals']=model_region_no_oldest.resid

fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(16,8))

sns.violinplot(x='group_size', y='Residuals',data=data_clean,
               
               widths=700,
               showextrema=True, ax=ax[0],alpha=0.02
               )
sns.scatterplot(x='group_size',y='Residuals',data=data_clean,ax=ax[1])

# %%
data_clean=train2.copy()
bins = np.array([0, 12, 24, 36, 48])
data_clean['car_age_cat']=bins[np.digitize(data_clean['car_age'], bins)-1]
data_clean['Residuals']=model_region_no_oldest.resid

fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(16,8))

sns.violinplot(x='car_age_cat', y='Residuals',data=data_clean,
               
               widths=700,
               showextrema=True, ax=ax[0],alpha=0.02
               )
sns.scatterplot(x='car_age',y='Residuals',data=data_clean,ax=ax[1])

# %%
data_clean=train2.copy()
bins = np.array([15, 30, 45, 60,75])
data_clean['age_youngest_cat']=bins[np.digitize(data_clean['age_youngest'], bins)-1]
data_clean['Residuals']=model_region_no_oldest.resid

fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(16,8))

sns.violinplot(x='age_youngest_cat', y='Residuals',data=data_clean,
               
               widths=700,
               showextrema=True, ax=ax[0],alpha=0.02
               )
sns.scatterplot(x='age_youngest',y='Residuals',data=data_clean,ax=ax[1])

# %%
data_clean=train2.copy()

data_clean['Residuals']=model_region_no_oldest.resid

fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(16,8))

sns.violinplot(x='C_previous', y='Residuals',data=data_clean,
               
               widths=700,
               showextrema=True, ax=ax[0],alpha=0.02
               )
sns.scatterplot(x='C_previous',y='Residuals',data=data_clean,ax=ax[1])

# %%
data_clean=train2.copy()

data_clean['Residuals']=model_region_no_oldest.resid

fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(16,8))

sns.violinplot(x='duration_previous', y='Residuals',data=data_clean,
               
               widths=700,
               showextrema=True, ax=ax[0],alpha=0.02
               )
sns.scatterplot(x='duration_previous',y='Residuals',data=data_clean,ax=ax[1])

# %% [markdown]
# From the analysis of the model residuals it can be concluded that:
#
# -Residues do not have a normal distribution, this is a bad indicator for a linear regression model
#
# -We have heteroscedasticity problems in some predictor variables

# %% [markdown]
# ----------

# %% [markdown]
# ### Exercise 9:
#
# #### 9.1
#
# Find the best Box-Cox transformation of `cost` used to fit `model_region_no_oldest`. What value do you get?

# %% [markdown]
# **Answer.**

# %%
from scipy import stats
_,fitted_lambda = stats.boxcox(train2['cost'])
round(fitted_lambda,2)
# Out:
# 0.5

# %%
_,fitted_lambda = stats.boxcox(train2['group_size'])
round(fitted_lambda,2)
# Out:
# -5.97

# %% [markdown]
# We should use the square root transformation

# %% [markdown]
# ----------

# %% [markdown]
# #### 9.2
#
# Refit `model_region_no_oldest`, but now with the transformation as suggested by the Box-Cox. Call it `model_region_no_oldest_box_cox`.

# %% [markdown]
# **Answer.**

# %%
formula='np.sqrt(cost) ~ Region + group_size + homeowner + car_age  + car_value + car_value*(age_youngest) + age_youngest  + C_previous + duration_previous + A + E + F + G+ I(age_youngest**2) + I(car_age**2)'
model_region_no_oldest_box_cox = smf.ols(formula = formula, 
                 data = train2).fit()
model_region_no_oldest_box_cox.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          np.sqrt(cost)   R-squared:                       0.373
# Model:                            OLS   Adj. R-squared:                  0.372
# Method:                 Least Squares   F-statistic:                     203.8
# Date:                Tue, 07 Jul 2020   Prob (F-statistic):               0.00
# Time:                        10:48:09   Log-Likelihood:                -13842.
# No. Observations:               12344   AIC:                         2.776e+04
# Df Residuals:                   12307   BIC:                         2.803e+04
# Df Model:                          36
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                      26.6796      0.467     57.179      0.000      25.765      27.594
# Region[T.Northeast]             0.6459      0.024     26.408      0.000       0.598       0.694
# Region[T.South]                 0.4727      0.020     23.370      0.000       0.433       0.512
# Region[T.West]                  0.2701      0.024     11.363      0.000       0.224       0.317
# car_value[T.b]                 -1.8567      0.578     -3.210      0.001      -2.991      -0.723
# car_value[T.c]                 -0.8257      0.470     -1.757      0.079      -1.747       0.095
# car_value[T.d]                 -1.0318      0.467     -2.211      0.027      -1.947      -0.117
# car_value[T.e]                 -0.8787      0.466     -1.886      0.059      -1.792       0.035
# car_value[T.f]                 -0.8481      0.466     -1.819      0.069      -1.762       0.066
# car_value[T.g]                 -0.7023      0.468     -1.500      0.134      -1.620       0.215
# car_value[T.h]                 -0.3585      0.477     -0.751      0.453      -1.294       0.577
# car_value[T.i]                  0.4601      0.577      0.797      0.425      -0.671       1.591
# A[T.1]                          0.8107      0.027     29.532      0.000       0.757       0.864
# A[T.2]                          0.9031      0.035     26.154      0.000       0.835       0.971
# E[T.1]                          0.2410      0.016     15.280      0.000       0.210       0.272
# F[T.1]                         -0.0810      0.026     -3.092      0.002      -0.132      -0.030
# F[T.2]                         -0.0702      0.026     -2.752      0.006      -0.120      -0.020
# F[T.3]                         -0.1517      0.044     -3.465      0.001      -0.238      -0.066
# G[T.2]                          0.2189      0.019     11.796      0.000       0.182       0.255
# G[T.3]                          0.1471      0.021      7.007      0.000       0.106       0.188
# G[T.4]                          0.1565      0.025      6.254      0.000       0.107       0.206
# group_size                      0.0038      0.015      0.250      0.803      -0.026       0.034
# homeowner                      -0.2742      0.015    -18.300      0.000      -0.304      -0.245
# car_age                        -0.0266      0.003     -8.115      0.000      -0.033      -0.020
# age_youngest                   -0.0542      0.008     -6.526      0.000      -0.070      -0.038
# car_value[T.b]:age_youngest     0.0158      0.011      1.420      0.156      -0.006       0.038
# car_value[T.c]:age_youngest     0.0041      0.008      0.501      0.616      -0.012       0.020
# car_value[T.d]:age_youngest     0.0108      0.008      1.348      0.178      -0.005       0.026
# car_value[T.e]:age_youngest     0.0078      0.008      0.972      0.331      -0.008       0.023
# car_value[T.f]:age_youngest     0.0070      0.008      0.878      0.380      -0.009       0.023
# car_value[T.g]:age_youngest     0.0055      0.008      0.692      0.489      -0.010       0.021
# car_value[T.h]:age_youngest     0.0013      0.008      0.152      0.879      -0.015       0.017
# car_value[T.i]:age_youngest    -0.0049      0.010     -0.474      0.636      -0.025       0.015
# C_previous                     -0.1354      0.006    -21.230      0.000      -0.148      -0.123
# duration_previous              -0.0278      0.002    -18.461      0.000      -0.031      -0.025
# I(age_youngest ** 2)            0.0004   2.62e-05     15.600      0.000       0.000       0.000
# I(car_age ** 2)                 0.0007      0.000      4.488      0.000       0.000       0.001
# ==============================================================================
# Omnibus:                      369.601   Durbin-Watson:                   1.851
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              865.671
# Skew:                           0.139   Prob(JB):                    1.05e-188
# Kurtosis:                       4.267   Cond. No.                     5.72e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.72e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
sm.qqplot(model_region_no_oldest_box_cox.resid, line="s");

# %% [markdown]
# ----------

# %% [markdown]
# ## Conclusion
#
# In this, you practiced creating linear models using `statsmodels` and iteratively trimming the input variables to go from including all the variables in the dataset to using only the most relevant variables. You excluded those variables that were statistically insignificant and removed those that had high correlation. Finally, we performed some feature engineering in an attempt to remove some tail behavior that deviates from the normal distribution to better fit our linear model. In the end, we had a very minimal model that contained variables that other insurance companies use to charge premiums that gave us insight on how we can better serve a niche population.
